# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="phpipamadmin",
  database="flowdata"
)

mycursor = mydb.cursor()
mycursor.execute("SHOW TABLES")
for x in mycursor:
    print(x)
mycursor.close()
# Out:
# ('netflow',)
# ('netflows',)
# True

# %%
mycursor = mydb.cursor()
mycursor.execute("CREATE TABLE p_netflow (srcaddr INT UNSIGNED, srcport MEDIUMINT UNSIGNED, first BIGINT UNSIGNED, last BIGINT UNSIGNED, protocol TINYINT UNSIGNED, flows SMALLINT UNSIGNED, packets MEDIUMINT UNSIGNED, bytes INT UNSIGNED, PRIMARY KEY(`srcaddr`)) \
ENGINE=InnoDB DEFAULT CHARSET=utf8 PARTITION BY HASH(srcaddr) partitions 64;")
mycursor.close()
# Out:
# True

# %%
import socket  
import struct  
  

ip = '127.0.0.1'  
int_ip = struct.unpack('!I', socket.inet_aton(ip))[0]  
print(int_ip)  
str_ip = socket.inet_ntoa(struct.pack('!I', int_ip))  
print(str_ip)
# Out:
# 2130706433
# 127.0.0.1

# %%
def protocol_to_number(protocol):
    if protocol == 'TCP':
        num = 1
    elif protocol=='UDP':
        num = 2
    elif protocol == 'ssh':
        num = 3
    return num

# %%
import time
import json

# update 1 X 1000000 records at a time

sql_update = "INSERT INTO p_netflow (srcaddr, srcport, first, last, protocol, flows, packets, bytes) VALUES (%s,%s,%s,%s,%s,%s,%s,%s) ON DUPLICATE KEY UPDATE `last` = VALUES(`last`), `flows`= VALUES(`flows`) + `flows`, `packets`= VALUES(`packets`) + `packets`, `bytes`= VALUES(`bytes`) + `bytes`"

#for json_name in s:
mycursor = mydb.cursor()
start_time = time.time()
flows = []
with open('data/netflow/20200528140758.json') as record:
        new_record = json.load(record)
        for flow in new_record:
            srcaddr = struct.unpack('!I', socket.inet_aton(flow["srcaddr"]))[0]
            protocol = protocol_to_number(flow["protocol"])
            flow_one = (srcaddr, flow["srcport"], flow["First"], flow["Last"], protocol, flow["flows"], flow["packets"], flow["bytes"])
            flows.append(flow_one)
        mycursor.executemany(sql_update, flows)
        mydb.commit()    # 数据表内容有更新，必须使用到该语句
        mycursor.close()
        print(mycursor.rowcount, "记录插入成功。")
        end_time = time.time()
        consume_time = end_time - start_time
        consume_time = '{:0>2s}'.format(str(int(consume_time // 3600))) \
               + ':{:0>2s}'.format(str(int((consume_time // 60) % 60))) \
               + ':{:0>2s}'.format(str(int(consume_time % 60)))
        print(consume_time)
# Out:
# -1 记录插入成功。
# 00:01:11

# %%
# Python read all files from a directory in order
import os

f = open("./data/netflow_name.txt", 'w')
path = "./data/netflow/"
files = os.listdir(path)
files.sort()

s = []

for file_name in files:
    if not os.path.isdir(path + file_name):
        f_name = str(file_name)
        print(f_name)
        s.append(f_name)
        f.write(f_name + '\n')
for i in s:
    print(i)
print(s)
# Out:
# 20200528140758.json
# 20200528141325.json
# 20200528141851.json
# 20200528142416.json
# 20200528142940.json
# 20200528143504.json
# 20200528144029.json
# 20200528144554.json
# 20200528145119.json
# 20200528145643.json
# 20200528150208.json
# 20200528150732.json
# 20200528151257.json
# 20200528151821.json
# 20200528152346.json
# 20200528152910.json
# 20200528153435.json
# 20200528153959.json
# 20200528154524.json
# 20200528155048.json
# 20200528155613.json
# 20200528160137.json
# 20200528160702.json
# 20200528161228.json
# 20200528161752.json
# 20200528162317.json
# 20200528162841.json
# 20200528163405.json
# 20200528163930.json
# 20200528164454.json
# 20200528165019.json
# 20200528165543.json
# 20200528170107.json
# 20200528170632.json
# 20200528171156.json
# 20200528171721.json
# 20200528172246.json
# 20200528172810.json
# 20200528173335.json
# 20200528173859.json
# 20200528174424.json
# 20200528174948.json
# 20200528175513.json
# 20200528180037.json
# 20200528180602.json
# 20200528181126.json
# 20200528181650.json
# 20200528182215.json
# 20200528182740.json
# 20200528183304.json
# 20200528183829.json
# 20200528184353.json
# 20200528184917.json
# 20200528185442.json
# 20200528190006.json
# 20200528190530.json
# 20200528191055.json
# 20200528191619.json
# 20200528192143.json
# 20200528192708.json
# 20200528193232.json
# 20200528193757.json
# 20200528194321.json
# 20200528194845.json
# 20200528195410.json
# 20200528195934.json
# 20200528200458.json
# 20200528201023.json
# 20200528201547.json
# 20200528202112.json
# 20200528202636.json
# 20200528203201.json
# 20200528203725.json
# 20200528204250.json
# 20200528204814.json
# 20200528205338.json
# 20200528205903.json
# 20200528210427.json
# 20200528210951.json
# 20200528211516.json
# 20200528212040.json
# 20200528212604.json
# 20200528213129.json
# 20200528213653.json
# 20200528214217.json
# 20200528214742.json
# 20200528215306.json
# 20200528215830.json
# 20200528220354.json
# 20200528220919.json
# 20200528221443.json
# 20200528222007.json
# 20200528222532.json
# 20200528223056.json
# 20200528223620.json
# 20200528224144.json
# 20200528224709.json
# 20200528225233.json
# 20200528225758.json
# 20200528230322.json
# 20200528230846.json
# 20200528231411.json
# 20200528231935.json
# 20200528232500.json
# 20200528233025.json
# 20200528233549.json
# 20200528234113.json
# 20200528234638.json
# 20200528235202.json
# 20200528235727.json
# 20200529000251.json
# 20200529000815.json
# 20200529001340.json
# 20200529001904.json
# 20200529002428.json
# 20200529002953.json
# 20200529003517.json
# 20200529004042.json
# 20200529004606.json
# 20200529005131.json
# 20200529005655.json
# 20200529010219.json
# 20200529010744.json
# 20200529011308.json
# 20200529011832.json
# 20200529012357.json
# 20200529012921.json
# 20200529013445.json
# 20200529014010.json
# 20200529014534.json
# 20200529015058.json
# 20200529015622.json
# 20200529020147.json
# 20200529020711.json
# 20200529021237.json
# 20200529021801.json
# 20200529022325.json
# 20200529022850.json
# 20200529023414.json
# 20200529023938.json
# 20200529024503.json
# 20200529025027.json
# 20200529025551.json
# 20200529030116.json
# 20200529030640.json
# 20200529031205.json
# 20200529031729.json
# 20200529032256.json
# 20200529032823.json
# 20200529033349.json
# 20200529033918.json
# 20200529034444.json
# 20200529035008.json
# 20200529035533.json
# 20200529040057.json
# 20200529040622.json
# 20200529041147.json
# 20200529041711.json
# 20200529042236.json
# 20200529042800.json
# 20200529043325.json
# 20200529043849.json
# 20200529044414.json
# 20200529044939.json
# 20200529045503.json
# 20200529050027.json
# 20200529050552.json
# 20200529051117.json
# 20200529051641.json
# 20200529052206.json
# 20200529052730.json
# 20200529053255.json
# 20200529053819.json
# 20200529054344.json
# 20200529054908.json
# 20200529055433.json
# 20200529055958.json
# 20200529060522.json
# 20200529061047.json
# 20200529061611.json
# 20200529062136.json
# 20200529062700.json
# 20200529063225.json
# 20200529063749.json
# 20200529064314.json
# 20200529064838.json
# 20200529065403.json
# 20200529065927.json
# 20200529070452.json
# 20200529071016.json
# 20200529071540.json
# 20200529072105.json
# 20200529072629.json
# 20200529073154.json
# 20200529073718.json
# 20200529074242.json
# 20200529074807.json
# 20200529075331.json
# 20200529075855.json
# 20200529080420.json
# 20200529080944.json
# 20200529081508.json
# 20200529082033.json
# 20200529082557.json
# 20200529083122.json
# 20200529083646.json
# 20200529084210.json
# 20200529084735.json
# 20200529085259.json
# 20200529085824.json
# 20200529090348.json
# 20200529090913.json
# 20200529091437.json
# 20200529092001.json
# 20200529092526.json
# 20200529093050.json
# 20200529093614.json
# 20200529094139.json
# 20200529094703.json
# 20200529095228.json
# 20200529095752.json
# 20200529100317.json
# 20200529100841.json
# 20200529101406.json
# 20200529101930.json
# 20200529102454.json
# 20200529103019.json
# 20200529103543.json
# 20200528140758.json
# 20200528141325.json
# 20200528141851.json
# 20200528142416.json
# 20200528142940.json
# 20200528143504.json
# 20200528144029.json
# 20200528144554.json
# 20200528145119.json
# 20200528145643.json
# 20200528150208.json
# 20200528150732.json
# 20200528151257.json
# 20200528151821.json
# 20200528152346.json
# 20200528152910.json
# 20200528153435.json
# 20200528153959.json
# 20200528154524.json
# 20200528155048.json
# 20200528155613.json
# 20200528160137.json
# 20200528160702.json
# 20200528161228.json
# 20200528161752.json
# 20200528162317.json
# 20200528162841.json
# 20200528163405.json
# 20200528163930.json
# 20200528164454.json
# 20200528165019.json
# 20200528165543.json
# 20200528170107.json
# 20200528170632.json
# 20200528171156.json
# 20200528171721.json
# 20200528172246.json
# 20200528172810.json
# 20200528173335.json
# 20200528173859.json
# 20200528174424.json
# 20200528174948.json
# 20200528175513.json
# 20200528180037.json
# 20200528180602.json
# 20200528181126.json
# 20200528181650.json
# 20200528182215.json
# 20200528182740.json
# 20200528183304.json
# 20200528183829.json
# 20200528184353.json
# 20200528184917.json
# 20200528185442.json
# 20200528190006.json
# 20200528190530.json
# 20200528191055.json
# 20200528191619.json
# 20200528192143.json
# 20200528192708.json
# 20200528193232.json
# 20200528193757.json
# 20200528194321.json
# 20200528194845.json
# 20200528195410.json
# 20200528195934.json
# 20200528200458.json
# 20200528201023.json
# 20200528201547.json
# 20200528202112.json
# 20200528202636.json
# 20200528203201.json
# 20200528203725.json
# 20200528204250.json
# 20200528204814.json
# 20200528205338.json
# 20200528205903.json
# 20200528210427.json
# 20200528210951.json
# 20200528211516.json
# 20200528212040.json
# 20200528212604.json
# 20200528213129.json
# 20200528213653.json
# 20200528214217.json
# 20200528214742.json
# 20200528215306.json
# 20200528215830.json
# 20200528220354.json
# 20200528220919.json
# 20200528221443.json
# 20200528222007.json
# 20200528222532.json
# 20200528223056.json
# 20200528223620.json
# 20200528224144.json
# 20200528224709.json
# 20200528225233.json
# 20200528225758.json
# 20200528230322.json
# 20200528230846.json
# 20200528231411.json
# 20200528231935.json
# 20200528232500.json
# 20200528233025.json
# 20200528233549.json
# 20200528234113.json
# 20200528234638.json
# 20200528235202.json
# 20200528235727.json
# 20200529000251.json
# 20200529000815.json
# 20200529001340.json
# 20200529001904.json
# 20200529002428.json
# 20200529002953.json
# 20200529003517.json
# 20200529004042.json
# 20200529004606.json
# 20200529005131.json
# 20200529005655.json
# 20200529010219.json
# 20200529010744.json
# 20200529011308.json
# 20200529011832.json
# 20200529012357.json
# 20200529012921.json
# 20200529013445.json
# 20200529014010.json
# 20200529014534.json
# 20200529015058.json
# 20200529015622.json
# 20200529020147.json
# 20200529020711.json
# 20200529021237.json
# 20200529021801.json
# 20200529022325.json
# 20200529022850.json
# 20200529023414.json
# 20200529023938.json
# 20200529024503.json
# 20200529025027.json
# 20200529025551.json
# 20200529030116.json
# 20200529030640.json
# 20200529031205.json
# 20200529031729.json
# 20200529032256.json
# 20200529032823.json
# 20200529033349.json
# 20200529033918.json
# 20200529034444.json
# 20200529035008.json
# 20200529035533.json
# 20200529040057.json
# 20200529040622.json
# 20200529041147.json
# 20200529041711.json
# 20200529042236.json
# 20200529042800.json
# 20200529043325.json
# 20200529043849.json
# 20200529044414.json
# 20200529044939.json
# 20200529045503.json
# 20200529050027.json
# 20200529050552.json
# 20200529051117.json
# 20200529051641.json
# 20200529052206.json
# 20200529052730.json
# 20200529053255.json
# 20200529053819.json
# 20200529054344.json
# 20200529054908.json
# 20200529055433.json
# 20200529055958.json
# 20200529060522.json
# 20200529061047.json
# 20200529061611.json
# 20200529062136.json
# 20200529062700.json
# 20200529063225.json
# 20200529063749.json
# 20200529064314.json
# 20200529064838.json
# 20200529065403.json
# 20200529065927.json
# 20200529070452.json
# 20200529071016.json
# 20200529071540.json
# 20200529072105.json
# 20200529072629.json
# 20200529073154.json
# 20200529073718.json
# 20200529074242.json
# 20200529074807.json
# 20200529075331.json
# 20200529075855.json
# 20200529080420.json
# 20200529080944.json
# 20200529081508.json
# 20200529082033.json
# 20200529082557.json
# 20200529083122.json
# 20200529083646.json
# 20200529084210.json
# 20200529084735.json
# 20200529085259.json
# 20200529085824.json
# 20200529090348.json
# 20200529090913.json
# 20200529091437.json
# 20200529092001.json
# 20200529092526.json
# 20200529093050.json
# 20200529093614.json
# 20200529094139.json
# 20200529094703.json
# 20200529095228.json
# 20200529095752.json
# 20200529100317.json
# 20200529100841.json
# 20200529101406.json
# 20200529101930.json
# 20200529102454.json
# 20200529103019.json
# 20200529103543.json
# ['20200528140758.json', '20200528141325.json', '20200528141851.json', '20200528142416.json', '20200528142940.json', '20200528143504.json', '20200528144029.json', '20200528144554.json', '20200528145119.json', '20200528145643.json', '20200528150208.json', '20200528150732.json', '20200528151257.json', '20200528151821.json', '20200528152346.json', '20200528152910.json', '20200528153435.json', '20200528153959.json', '20200528154524.json', '20200528155048.json', '20200528155613.json', '20200528160137.json', '20200528160702.json', '20200528161228.json', '20200528161752.json', '20200528162317.json', '20200528162841.json', '20200528163405.json', '20200528163930.json', '20200528164454.json', '20200528165019.json', '20200528165543.json', '20200528170107.json', '20200528170632.json', '20200528171156.json', '20200528171721.json', '20200528172246.json', '20200528172810.json', '20200528173335.json', '20200528173859.json', '20200528174424.json', '20200528174948.json', '20200528175513.json', '20200528180037.json', '20200528180602.json', '20200528181126.json', '20200528181650.json', '20200528182215.json', '20200528182740.json', '20200528183304.json', '20200528183829.json', '20200528184353.json', '20200528184917.json', '20200528185442.json', '20200528190006.json', '20200528190530.json', '20200528191055.json', '20200528191619.json', '20200528192143.json', '20200528192708.json', '20200528193232.json', '20200528193757.json', '20200528194321.json', '20200528194845.json', '20200528195410.json', '20200528195934.json', '20200528200458.json', '20200528201023.json', '20200528201547.json', '20200528202112.json', '20200528202636.json', '20200528203201.json', '20200528203725.json', '20200528204250.json', '20200528204814.json', '20200528205338.json', '20200528205903.json', '20200528210427.json', '20200528210951.json', '20200528211516.json', '20200528212040.json', '20200528212604.json', '20200528213129.json', '20200528213653.json', '20200528214217.json', '20200528214742.json', '20200528215306.json', '20200528215830.json', '20200528220354.json', '20200528220919.json', '20200528221443.json', '20200528222007.json', '20200528222532.json', '20200528223056.json', '20200528223620.json', '20200528224144.json', '20200528224709.json', '20200528225233.json', '20200528225758.json', '20200528230322.json', '20200528230846.json', '20200528231411.json', '20200528231935.json', '20200528232500.json', '20200528233025.json', '20200528233549.json', '20200528234113.json', '20200528234638.json', '20200528235202.json', '20200528235727.json', '20200529000251.json', '20200529000815.json', '20200529001340.json', '20200529001904.json', '20200529002428.json', '20200529002953.json', '20200529003517.json', '20200529004042.json', '20200529004606.json', '20200529005131.json', '20200529005655.json', '20200529010219.json', '20200529010744.json', '20200529011308.json', '20200529011832.json', '20200529012357.json', '20200529012921.json', '20200529013445.json', '20200529014010.json', '20200529014534.json', '20200529015058.json', '20200529015622.json', '20200529020147.json', '20200529020711.json', '20200529021237.json', '20200529021801.json', '20200529022325.json', '20200529022850.json', '20200529023414.json', '20200529023938.json', '20200529024503.json', '20200529025027.json', '20200529025551.json', '20200529030116.json', '20200529030640.json', '20200529031205.json', '20200529031729.json', '20200529032256.json', '20200529032823.json', '20200529033349.json', '20200529033918.json', '20200529034444.json', '20200529035008.json', '20200529035533.json', '20200529040057.json', '20200529040622.json', '20200529041147.json', '20200529041711.json', '20200529042236.json', '20200529042800.json', '20200529043325.json', '20200529043849.json', '20200529044414.json', '20200529044939.json', '20200529045503.json', '20200529050027.json', '20200529050552.json', '20200529051117.json', '20200529051641.json', '20200529052206.json', '20200529052730.json', '20200529053255.json', '20200529053819.json', '20200529054344.json ...

# %%
import time
import json

# update 288 X 1000000 records at a time

sql_update = "INSERT INTO p_netflow (srcaddr, srcport, first, last, protocol, flows, packets, bytes) VALUES (%s,%s,%s,%s,%s,%s,%s,%s) ON DUPLICATE KEY UPDATE `last` = VALUES(`last`), `flows`= VALUES(`flows`) + `flows`, `packets`= VALUES(`packets`) + `packets`, `bytes`= VALUES(`bytes`) + `bytes`"

for json_name in s:
    mycursor = mydb.cursor()
    start_time = time.time()
    flows = []
    with open('data/netflow/' + json_name) as record:
        new_record = json.load(record)
        for flow in new_record:
            srcaddr = struct.unpack('!I', socket.inet_aton(flow["srcaddr"]))[0]
            protocol = protocol_to_number(flow["protocol"])
            flow_one = (srcaddr, flow["srcport"], flow["First"], flow["Last"], protocol, flow["flows"], flow["packets"], flow["bytes"])
            flows.append(flow_one)
        mycursor.executemany(sql_update, flows)
        mydb.commit()    # 数据表内容有更新，必须使用到该语句
        mycursor.close()
        print(mycursor.rowcount, "记录插入成功。")
        end_time = time.time()
        consume_time = end_time - start_time
        consume_time = '{:0>2s}'.format(str(int(consume_time // 3600))) \
               + ':{:0>2s}'.format(str(int((consume_time // 60) % 60))) \
               + ':{:0>2s}'.format(str(int(consume_time % 60)))
        print(consume_time)
# Out:
# -1 记录插入成功。
# 00:00:55
# -1 记录插入成功。
# 00:02:20
# -1 记录插入成功。
# 00:06:33
# -1 记录插入成功。
# 00:10:35
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-2b7c1d60a3f6> in <module>
#      17             flow_one = (srcaddr, flow["srcport"], flow["First"], flow["Last"], protocol, flow["flows"], flow["packets"], flow["bytes"])
#      18             flows.append(flow_one)
# ---> 19         mycursor.executemany(sql_update, flows)
#      20         mydb.commit()    # 数据表内容有更新，必须使用到该语句
#      21         mycursor.close()
#
# ~/environments/my_env/lib/python3.6/site-packages/mysql/connector/cursor.py in executemany(self, operation, seq_params)
#     652             stmt = self._batch_insert(operation, seq_params)
#     653             if stmt is not None:
# --> 654                 return self.execute(stmt)
#     655
#     656         rowcnt = 0
#
# ~/environments/my_env/lib/python3.6/site-packages/mysql/connector/cursor.py in execute(self, operation, params, multi)
#     549         else:
#     550             try:
# --> 551                 self._handle_result(self._connection.cmd_query(stmt))
#     552             except errors.InterfaceError:
#     553                 if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~/environments/my_env/lib/python3.6/site-packages/mysql/connector/connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     488         if not isinstance(query, bytes):
#     489             query = query.encode('utf-8')
# --> 490         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     491
#     492         if self._have_next_result:
#
# ~/environments/my_env/lib/python3.6/site-packages/mysql/connector/connection.py in _send_cmd(self, command, argument, packet_number, packet, expect_response, compressed_packet_number)
#     265         if not expect_response:
#     266             return None
# --> 267         return self._socket.recv()
#     268
#     269     def _send_data(self, data_file, send_empty_packet=False):
#
# ~/environments/my_env/lib/python3.6/site-packages/mysql/connector/network.py in recv_plain(self)
#     239             packet_len = 0
#     240             while packet_len < 4:
# --> 241                 chunk = self.sock.recv(4 - packet_len)
#     242                 if not chunk:
#     243                     raise errors.InterfaceError(errno=2013)
#
# KeyboardInterrupt:

# %%
import time
import json

# update 288 X 1000000 records at a time

sql_update = "INSERT INTO p_netflow (srcaddr, srcport, first, last, protocol, flows, packets, bytes) VALUES (%s,%s,%s,%s,%s,%s,%s,%s) ON DUPLICATE KEY UPDATE `last` = VALUES(`last`), `flows`= VALUES(`flows`) + `flows`, `packets`= VALUES(`packets`) + `packets`, `bytes`= VALUES(`bytes`) + `bytes`"

for json_name in s:
    mydb.pool_reset_connections()
    mycursor = mydb.cursor()
    start_time = time.time()
    flows = []
    with open('data/netflow/' + json_name) as record:
        new_record = json.load(record)
        for flow in new_record:
            srcaddr = struct.unpack('!I', socket.inet_aton(flow["srcaddr"]))[0]
            protocol = protocol_to_number(flow["protocol"])
            flow_one = (srcaddr, flow["srcport"], flow["First"], flow["Last"], protocol, flow["flows"], flow["packets"], flow["bytes"])
            flows.append(flow_one)
        mycursor.executemany(sql_update, flows)
        mydb.commit()    # 数据表内容有更新，必须使用到该语句
        mycursor.close()

        print(mycursor.rowcount, "记录插入成功。")
        end_time = time.time()
        consume_time = end_time - start_time
        consume_time = '{:0>2s}'.format(str(int(consume_time // 3600))) \
               + ':{:0>2s}'.format(str(int((consume_time // 60) % 60))) \
               + ':{:0>2s}'.format(str(int(consume_time % 60)))
        print(consume_time)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-22f3857d8785> in <module>
#       7
#       8 for json_name in s:
# ----> 9     mydb.pool_reset_connections()
#      10     mycursor = mydb.cursor()
#      11     start_time = time.time()
#
# AttributeError: 'MySQLConnection' object has no attribute 'pool_reset_connections'

# %%
import time
import json

# update 1 X 1000000 records at a time

sql_update = "INSERT INTO p_netflow (srcaddr, srcport, first, last, protocol, flows, packets, bytes) VALUES (%s,%s,%s,%s,%s,%s,%s,%s) ON DUPLICATE KEY UPDATE `last` = VALUES(`last`), `flows`= VALUES(`flows`) + `flows`, `packets`= VALUES(`packets`) + `packets`, `bytes`= VALUES(`bytes`) + `bytes`"

#for json_name in s:
mycursor = mydb.cursor()
start_time = time.time()
flows = []
with open('data/netflow/20200528142940.json') as record:
        new_record = json.load(record)
        for flow in new_record:
            srcaddr = struct.unpack('!I', socket.inet_aton(flow["srcaddr"]))[0]
            protocol = protocol_to_number(flow["protocol"])
            flow_one = (srcaddr, flow["srcport"], flow["First"], flow["Last"], protocol, flow["flows"], flow["packets"], flow["bytes"])
            flows.append(flow_one)
        mycursor.executemany(sql_update, flows)
        mydb.commit()    # 数据表内容有更新，必须使用到该语句
        mycursor.close()
        print(mycursor.rowcount, "记录插入成功。")
        end_time = time.time()
        consume_time = end_time - start_time
        consume_time = '{:0>2s}'.format(str(int(consume_time // 3600))) \
               + ':{:0>2s}'.format(str(int((consume_time // 60) % 60))) \
               + ':{:0>2s}'.format(str(int(consume_time % 60)))
        print(consume_time)
# Out:
# -1 记录插入成功。
# 00:11:00

# %%
mydb.close()

# %%
mydb.reconnect()
mydb.close()

# %%
import time
import json

# update 1 X 1000000 records at a time

sql_update = "INSERT INTO p_netflow (srcaddr, srcport, first, last, protocol, flows, packets, bytes) VALUES (%s,%s,%s,%s,%s,%s,%s,%s) ON DUPLICATE KEY UPDATE `last` = VALUES(`last`), `flows`= VALUES(`flows`) + `flows`, `packets`= VALUES(`packets`) + `packets`, `bytes`= VALUES(`bytes`) + `bytes`"
mydb.reconnect()
#for json_name in s:
mycursor = mydb.cursor()
start_time = time.time()
flows = []
with open('data/test data/test_data.json') as record:
        new_record = json.load(record)
        for flow in new_record:
            srcaddr = struct.unpack('!I', socket.inet_aton(flow["srcaddr"]))[0]
            protocol = protocol_to_number(flow["protocol"])
            flow_one = (srcaddr, flow["srcport"], flow["First"], flow["Last"], protocol, flow["flows"], flow["packets"], flow["bytes"])
            flows.append(flow_one)
        mycursor.executemany(sql_update, flows)
        mydb.commit()    # 数据表内容有更新，必须使用到该语句
        mycursor.close()
        print(mycursor.rowcount, "记录插入成功。")
        end_time = time.time()
        consume_time = end_time - start_time
        consume_time = '{:0>2s}'.format(str(int(consume_time // 3600))) \
               + ':{:0>2s}'.format(str(int((consume_time // 60) % 60))) \
               + ':{:0>2s}'.format(str(int(consume_time % 60)))
        print(consume_time) 
        
mydb.close()
# Out:
# -1 记录插入成功。
# 00:00:00

# %%
import time
import json

# update 1 X 1000000 records at a time
mydb.reconnect()
#for json_name in s:
mycursor = mydb.cursor()
sql_update = "INSERT INTO p_netflow (srcaddr, srcport, first, last, protocol, flows, packets, bytes) VALUES (%s,%s,%s,%s,%s,%s,%s,%s) ON DUPLICATE KEY UPDATE `last` = VALUES(`last`), `flows`= VALUES(`flows`) + `flows`, `packets`= VALUES(`packets`) + `packets`, `bytes`= VALUES(`bytes`) + `bytes`"

start_time = time.time()
flows = []
#i = 0
with open('data/netflow/' + s[1]) as record:
        new_record = json.load(record)
        for flow in new_record:
            #i = i + 1
            srcaddr = struct.unpack('!I', socket.inet_aton(flow["srcaddr"]))[0]
            protocol = protocol_to_number(flow["protocol"])
            flow_one = (srcaddr, flow["srcport"], flow["First"], flow["Last"], protocol, flow["flows"], flow["packets"], flow["bytes"])
            flows.append(flow_one)
            #if i == 100000:
                #mycursor.executemany(sql_update, flows)
                #mydb.commit()    # 数据表内容有更新，必须使用到该语句
                #mycursor.close()
                #mydb.close()
                #mydb.reconnect()
                #for json_name in s:
                #mycursor = mydb.cursor()
                #i = 0
        mycursor.executemany(sql_update, flows)
        mycursor.close()
        mydb.commit()    # 数据表内容有更新，必须使用到该语句
        mydb.close()
        print(mycursor.rowcount, "记录插入成功。")
        end_time = time.time()
        consume_time = end_time - start_time
        consume_time = '{:0>2s}'.format(str(int(consume_time // 3600))) \
               + ':{:0>2s}'.format(str(int((consume_time // 60) % 60))) \
               + ':{:0>2s}'.format(str(int(consume_time % 60)))
        print(consume_time)
# Out:
# -1 记录插入成功。
# 00:01:14

# %%
with open('data/netflow/' + s[7]) as record:
    new_record = json.load(record)
    flow = new_record[35091]['flows']
    print(flow)
# Out:
# 29

# %%
len(new_record)
# Out:
# 1000000

# %%
type(new_record[1])
# Out:
# dict

# %%
new_record
# Out:
# [{'srcaddr': '117.177.185.198',
#   'srcport': 45389,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 28,
#   'packets': 423,
#   'bytes': 604229},
#  {'srcaddr': '230.222.229.60',
#   'srcport': 48206,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 30,
#   'packets': 233,
#   'bytes': 974938},
#  {'srcaddr': '101.46.189.58',
#   'srcport': 23698,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 25,
#   'packets': 160,
#   'bytes': 155269},
#  {'srcaddr': '70.116.230.20',
#   'srcport': 26855,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 20,
#   'packets': 302,
#   'bytes': 739921},
#  {'srcaddr': '173.0.182.44',
#   'srcport': 22806,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 10,
#   'packets': 85,
#   'bytes': 309136},
#  {'srcaddr': '3.187.110.88',
#   'srcport': 33811,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 18,
#   'packets': 476,
#   'bytes': 800950},
#  {'srcaddr': '73.98.60.170',
#   'srcport': 44967,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 10,
#   'packets': 399,
#   'bytes': 765569},
#  {'srcaddr': '88.50.53.78',
#   'srcport': 38156,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 2,
#   'packets': 384,
#   'bytes': 740932},
#  {'srcaddr': '80.144.221.197',
#   'srcport': 55239,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 13,
#   'packets': 361,
#   'bytes': 890957},
#  {'srcaddr': '5.21.97.195',
#   'srcport': 10930,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 1,
#   'packets': 86,
#   'bytes': 893537},
#  {'srcaddr': '185.166.136.237',
#   'srcport': 18100,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 0,
#   'packets': 452,
#   'bytes': 949348},
#  {'srcaddr': '76.47.56.61',
#   'srcport': 50482,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 9,
#   'packets': 297,
#   'bytes': 521603},
#  {'srcaddr': '17.186.38.47',
#   'srcport': 37695,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 6,
#   'packets': 217,
#   'bytes': 908473},
#  {'srcaddr': '20.30.112.32',
#   'srcport': 13576,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 25,
#   'packets': 342,
#   'bytes': 956949},
#  {'srcaddr': '223.109.163.120',
#   'srcport': 10534,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 7,
#   'packets': 264,
#   'bytes': 86902},
#  {'srcaddr': '131.152.9.121',
#   'srcport': 23547,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 20,
#   'packets': 24,
#   'bytes': 469745},
#  {'srcaddr': '90.199.173.194',
#   'srcport': 12857,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 4,
#   'packets': 235,
#   'bytes': 299406},
#  {'srcaddr': '79.94.111.19',
#   'srcport': 25972,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 11,
#   'packets': 185,
#   'bytes': 409170},
#  {'srcaddr': '90.0.70.60',
#   'srcport': 15248,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 25,
#   'packets': 12,
#   'bytes': 862645},
#  {'srcaddr': '122.11.13.32',
#   'srcport': 56220,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 29,
#   'packets': 251,
#   'bytes': 123586},
#  {'srcaddr': '144.164.33.51',
#   'srcport': 48885,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 25,
#   'packets': 15,
#   'bytes': 560811},
#  {'srcaddr': '59.50.6.148',
#   'srcport': 27577,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 10,
#   'packets': 10,
#   'bytes': 755069},
#  {'srcaddr': '151.71.50.93',
#   'srcport': 52254,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 30,
#   'packets': 171,
#   'bytes': 155120},
#  {'srcaddr': '32.75.215.60',
#   'srcport': 49676,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 13,
#   'packets': 324,
#   'bytes': 42439},
#  {'srcaddr': '84.251.156.167',
#   'srcport': 46491,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 14,
#   'packets': 332,
#   'bytes': 373891},
#  {'srcaddr': '138.195.232.248',
#   'srcport': 20226,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 10,
#   'packets': 486,
#   'bytes': 520136},
#  {'srcaddr': '177.164.164.255',
#   'srcport': 6310,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 3,
#   'packets': 62,
#   'bytes': 611763},
#  {'srcaddr': '83.136.75.154',
#   'srcport': 17158,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 24,
#   'packets': 60,
#   'bytes': 272294},
#  {'srcaddr': '131.195.98.111',
#   'srcport': 26065,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 25,
#   'packets': 135,
#   'bytes': 148630},
#  {'srcaddr': '190.221.109.28',
#   'srcport': 37764,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 8,
#   'packets': 309,
#   'bytes': 879293},
#  {'srcaddr': '142.97.184.90',
#   'srcport': 9326,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 21,
#   'packets': 0,
#   'bytes': 166661},
#  {'srcaddr': '9.233.182.16',
#   'srcport': 50088,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 14,
#   'packets': 171,
#   'bytes': 978114},
#  {'srcaddr': '32.207.117.198',
#   'srcport': 42980,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 4,
#   'packets': 123,
#   'bytes': 805045},
#  {'srcaddr': '145.25.208.123',
#   'srcport': 10021,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 3,
#   'packets': 297,
#   'bytes': 57810},
#  {'srcaddr': '167.147.77.148',
#   'srcport': 7126,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 4,
#   'packets': 116,
#   'bytes': 522686},
#  {'srcaddr': '31.53.216.148',
#   'srcport': 21203,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 27,
#   'packets': 28,
#   'bytes': 115073},
#  {'srcaddr': '145.72.73.35',
#   'srcport': 34258,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 23,
#   'packets': 130,
#   'bytes': 423671},
#  {'srcaddr': '148.217.43.86',
#   'srcport': 58383,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 18,
#   'packets': 356,
#   'bytes': 435250},
#  {'srcaddr': '31.4.157.213',
#   'srcport': 40600,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 17,
#   'packets': 181,
#   'bytes': 344989},
#  {'srcaddr': '73.192.69.96',
#   'srcport': 14858,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 13,
#   'packets': 445,
#   'bytes': 538828},
#  {'srcaddr': '52.73.221.185',
#   'srcport': 30478,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 3,
#   'packets': 419,
#   'bytes': 455658},
#  {'srcaddr': '32.88.35.11',
#   'srcport': 41594,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 0,
#   'packets': 256,
#   'bytes': 125411},
#  {'srcaddr': '184.241.123.33',
#   'srcport': 40883,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 0,
#   'packets': 145,
#   'bytes': 945686},
#  {'srcaddr': '200.43.61.210',
#   'srcport': 27286,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 9,
#   'packets': 399,
#   'bytes': 938863},
#  {'srcaddr': '60.125.239.219',
#   'srcport': 33392,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 6,
#   'packets': 244,
#   'bytes': 715293},
#  {'srcaddr': '174.17.44.74',
#   'srcport': 64403,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 10,
#   'packets': 279,
#   'bytes': 190877},
#  {'srcaddr': '173.99.253.157',
#   'srcport': 3904,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 12,
#   'packets': 257,
#   'bytes': 690342},
#  {'srcaddr': '158.123.1.34',
#   'srcport': 5619,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 14,
#   'packets': 160,
#   'bytes': 683958},
#  {'srcaddr': '9.110.56.232',
#   'srcport': 51865,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 11,
#   'packets': 277,
#   'bytes': 755547},
#  {'srcaddr': '121.105.242.220',
#   'srcport': 6933,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 18,
#   'packets': 161,
#   'bytes': 222386},
#  {'srcaddr': '128.107.231.140',
#   'srcport': 32438,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 20,
#   'packets': 296,
#   'bytes': 809610},
#  {'srcaddr': '122.153.227.89',
#   'srcport': 21488,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 17,
#   'packets': 19,
#   'bytes': 930998},
#  {'srcaddr': '86.193.14.216',
#   'srcport': 44346,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 14,
#   'packets': 128,
#   'bytes': 88559},
#  {'srcaddr': '7.200.234.96',
#   'srcport': 38093,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 30,
#   'packets': 404,
#   'bytes': 770146},
#  {'srcaddr': '63.114.13.102',
#   'srcport': 41946,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 11,
#   'packets': 61,
#   'bytes': 888861},
#  {'srcaddr': '39.5.70.85',
#   'srcport': 59119,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 8,
#   'packets': 140,
#   'bytes': 434868},
#  {'srcaddr': '147.165.102.220',
#   'srcport': 26380,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 30,
#   'packets': 150,
#   'bytes': 647763},
#  {'srcaddr': '174.27.153.6',
#   'srcport': 34813,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 28,
#   'packets': 179,
#   'bytes': 975341},
#  {'srcaddr': '88.69.186.81',
#   'srcport': 11451,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 27,
#   'packets': 467,
#   'bytes': 455800},
#  {'srcaddr': '201.174.12.147',
#   'srcport': 8215,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 28,
#   'packets': 110,
#   'bytes': 250527},
#  {'srcaddr': '232.0.120.81',
#   'srcport': 46664,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 19,
#   'packets': 414,
#   'bytes': 679031},
#  {'srcaddr': '134.80.101.73',
#   'srcport': 27949,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 7,
#   'packets': 199,
#   'bytes': 510148},
#  {'srcaddr': '108.102.114.14',
#   'srcport': 20424,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 0,
#   'packets': 306,
#   'bytes': 806699},
#  {'srcaddr': '212.172.159.182',
#   'srcport': 11319,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 16,
#   'packets': 306,
#   'bytes': 48067},
#  {'srcaddr': '192.244.214.161',
#   'srcport': 53367,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 15,
#   'packets': 369,
#   'bytes': 784092},
#  {'srcaddr': '103.138.42.19',
#   'srcport': 20167,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 3,
#   'packets': 222,
#   'bytes': 103004},
#  {'srcaddr': '245.36.142.106',
#   'srcport': 43714,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 21,
#   'packets': 75,
#   'bytes': 689383},
#  {'srcaddr': '154.194.247.186',
#   'srcport': 27869,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 24,
#   'packets': 413,
#   'bytes': 378249},
#  {'srcaddr': '128.93.25.165',
#   'srcport': 6966,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 30,
#   'packets': 144,
#   'bytes': 418088},
#  {'srcaddr': '116.109.71.208',
#   'srcport': 40969,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 4,
#   'packets': 295,
#   'bytes': 246568},
#  {'srcaddr': '164.224.144.241',
#   'srcport': 29240,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 26,
#   'packets': 20,
#   'bytes': 140756},
#  {'srcaddr': '87.37.139.197',
#   'srcport': 58551,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 15,
#   'packets': 93,
#   'bytes': 823439},
#  {'srcaddr': '143.52.9.215',
#   'srcport': 4686,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 25,
#   'packets': 276,
#   'bytes': 112961},
#  {'srcaddr': '219.246.132.236',
#   'srcport': 54887,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 15,
#   'packets': 335,
#   'bytes': 789755},
#  {'srcaddr': '153.228.153.239',
#   'srcport': 42052,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 22,
#   'packets': 202,
#   'bytes': 47598},
#  {'srcaddr': '233.21.243.65',
#   'srcport': 4437,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 11,
#   'packets': 239,
#   'bytes': 703377},
#  {'srcaddr': '150.162.32.74',
#   'srcport': 53876,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 5,
#   'packets': 196,
#   'bytes': 689316},
#  {'srcaddr': '194.235.113.218',
#   'srcport': 13177,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 10,
#   'packets': 61,
#   'bytes': 844160},
#  {'srcaddr': '199.234.245.100',
#   'srcport': 10788,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 16,
#   'packets': 338,
#   'bytes': 415511},
#  {'srcaddr': '147.146.196.30',
#   'srcport': 47602,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 3,
#   'packets': 265,
#   'bytes': 237645},
#  {'srcaddr': '209.118.58.82',
#   'srcport': 8604,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 29,
#   'packets': 277,
#   'bytes': 545814},
#  {'srcaddr': '230.162.152.194',
#   'srcport': 14061,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 5,
#   'packets': 493,
#   'bytes': 182422},
#  {'srcaddr': '31.11.6.83',
#   'srcport': 27563,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 17,
#   'packets': 294,
#   'bytes': 718436},
#  {'srcaddr': '233.24.141.88',
#   'srcport': 51414,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 19,
#   'packets': 256,
#   'bytes': 944831},
#  {'srcaddr': '240.229.179.89',
#   'srcport': 21064,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 10,
#   'packets': 290,
#   'bytes': 602615},
#  {'srcaddr': '175.190.165.80',
#   'srcport': 57256,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 28,
#   'packets': 221,
#   'bytes': 665746},
#  {'srcaddr': '68.166.90.143',
#   'srcport': 32847,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 25,
#   'packets': 363,
#   'bytes': 291856},
#  {'srcaddr': '104.128.36.124',
#   'srcport': 46194,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 20,
#   'packets': 194,
#   'bytes': 507885},
#  {'srcaddr': '225.51.64.194',
#   'srcport': 63852,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 15,
#   'packets': 38,
#   'bytes': 544493},
#  {'srcaddr': '50.101.243.207',
#   'srcport': 54369,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 13,
#   'packets': 99,
#   'bytes': 170968},
#  {'srcaddr': '130.214.203.153',
#   'srcport': 28019,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 17,
#   'packets': 193,
#   'bytes': 264610},
#  {'srcaddr': '64.2.216.179',
#   'srcport': 61039,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 7,
#   'packets': 15,
#   'bytes': 362680},
#  {'srcaddr': '214.138.115.134',
#   'srcport': 55104,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 21,
#   'packets': 42,
#   'bytes': 327177},
#  {'srcaddr': '186.96.162.130',
#   'srcport': 10132,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 11,
#   'packets': 21,
#   'bytes': 974756},
#  {'srcaddr': '223.63.50.51',
#   'srcport': 61492,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 0,
#   'packets': 451,
#   'bytes': 86772},
#  {'srcaddr': '108.102.232.15',
#   'srcport': 5039,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 1,
#   'packets': 141,
#   'bytes': 126115},
#  {'srcaddr': '134.144.21.189',
#   'srcport': 7417,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 7,
#   'packets': 224,
#   'bytes': 155713},
#  {'srcaddr': '21.228.71.157',
#   'srcport': 30369,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 5,
#   'packets': 258,
#   'bytes': 760556},
#  {'srcaddr': '187.31.141.0',
#   'srcport': 50653,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 17,
#   'packets': 357,
#   'bytes': 185420},
#  {'srcaddr': '94.218.79.131',
#   'srcport': 23755,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 16,
#   'packets': 117,
#   'bytes': 328743},
#  {'srcaddr': '208.121.92.28',
#   'srcport': 35508,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 22,
#   'packets': 161,
#   'bytes': 857778},
#  {'srcaddr': '143.227.238.145',
#   'srcport': 44143,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 4,
#   'packets': 253,
#   'bytes': 552409},
#  {'srcaddr': '153.4.165.40',
#   'srcport': 62412,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 20,
#   'packets': 476,
#   'bytes': 777069},
#  {'srcaddr': '120.160.101.246',
#   'srcport': 53013,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 23,
#   'packets': 366,
#   'bytes': 892289},
#  {'srcaddr': '15.13.124.34',
#   'srcport': 43266,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 4,
#   'packets': 239,
#   'bytes': 967492},
#  {'srcaddr': '222.79.206.235',
#   'srcport': 5295,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 25,
#   'packets': 446,
#   'bytes': 25034},
#  {'srcaddr': '164.244.206.141',
#   'srcport': 1617,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 7,
#   'packets': 386,
#   'bytes': 3541},
#  {'srcaddr': '67.61.172.145',
#   'srcport': 36038,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 19,
#   'packets': 101,
#   'bytes': 812599},
#  {'srcaddr': '152.237.11.220',
#   'srcport': 61504,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 19,
#   'packets': 292,
#   'bytes': 857589},
#  {'srcaddr': '178.119.148.4',
#   'srcport': 6435,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 29,
#   'packets': 14,
#   'bytes': 523868},
#  {'srcaddr': '198.27.75.251',
#   'srcport': 492,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 8,
#   'packets': 181,
#   'bytes': 658030},
#  {'srcaddr': '103.150.80.174',
#   'srcport': 25413,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 11,
#   'packets': 104,
#   'bytes': 238433},
#  {'srcaddr': '183.84.101.232',
#   'srcport': 57445,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 12,
#   'packets': 436,
#   'bytes': 545702},
#  {'srcaddr': '142.255.156.82',
#   'srcport': 18158,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 17,
#   'packets': 436,
#   'bytes': 918877},
#  {'srcaddr': '117.230.73.62',
#   'srcport': 11079,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 3,
#   'packets': 153,
#   'bytes': 878141},
#  {'srcaddr': '163.22.129.111',
#   'srcport': 781,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 30,
#   'packets': 133,
#   'bytes': 26546},
#  {'srcaddr': '11.88.145.152',
#   'srcport': 32615,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 10,
#   'packets': 497,
#   'bytes': 280970},
#  {'srcaddr': '78.163.110.157',
#   'srcport': 57819,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 14,
#   'packets': 394,
#   'bytes': 815631},
#  {'srcaddr': '50.94.8.24',
#   'srcport': 62161,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 29,
#   'packets': 366,
#   'bytes': 818574},
#  {'srcaddr': '97.179.215.36',
#   'srcport': 29804,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 28,
#   'packets': 0,
#   'bytes': 632967},
#  {'srcaddr': '6.92.66.72',
#   'srcport': 20206,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 27,
#   'packets': 431,
#   'bytes': 463010},
#  {'srcaddr': '141.232.204.186',
#   'srcport': 23325,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 0,
#   'packets': 133,
#   'bytes': 188358},
#  {'srcaddr': '111.79.4.132',
#   'srcport': 6824,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 9,
#   'packets': 330,
#   'bytes': 507689},
#  {'srcaddr': '79.227.229.161',
#   'srcport': 42632,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 27,
#   'packets': 435,
#   'bytes': 216228},
#  {'srcaddr': '27.109.147.225',
#   'srcport': 26737,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 30,
#   'packets': 31,
#   'bytes': 986638},
#  {'srcaddr': '225.73.8.170',
#   'srcport': 35535,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 18,
#   'packets': 227,
#   'bytes': 807858},
#  {'srcaddr': '177.213.146.171',
#   'srcport': 31113,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 15,
#   'packets': 439,
#   'bytes': 99440},
#  {'srcaddr': '95.4.82.41',
#   'srcport': 35316,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 0,
#   'packets': 490,
#   'bytes': 775483},
#  {'srcaddr': '212.49.130.57',
#   'srcport': 63168,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 10,
#   'packets': 245,
#   'bytes': 981175},
#  {'srcaddr': '2.154.89.200',
#   'srcport': 512,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 0,
#   'packets': 160,
#   'bytes': 384622},
#  {'srcaddr': '7.144.172.67',
#   'srcport': 3341,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 30,
#   'packets': 179,
#   'bytes': 555723},
#  {'srcaddr': '192.225.169.48',
#   'srcport': 30355,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 22,
#   'packets': 65,
#   'bytes': 951358},
#  {'srcaddr': '93.194.37.117',
#   'srcport': 56518,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 15,
#   'packets': 442,
#   'bytes': 40821},
#  {'srcaddr': '226.66.75.104',
#   'srcport': 14203,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 3,
#   'packets': 499,
#   'bytes': 85548},
#  {'srcaddr': '152.68.249.161',
#   'srcport': 44533,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 7,
#   'packets': 379,
#   'bytes': 809786},
#  {'srcaddr': '11.223.120.248',
#   'srcport': 20754,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 21,
#   'packets': 134,
#   'bytes': 273794},
#  {'srcaddr': '75.84.157.92',
#   'srcport': 30381,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 3,
#   'packets': 47,
#   'bytes': 241827},
#  {'srcaddr': '249.221.207.231',
#   'srcport': 52347,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 17,
#   'packets': 16,
#   'bytes': 567770},
#  {'srcaddr': '68.48.3.12',
#   'srcport': 40041,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 29,
#   'packets': 304,
#   'bytes': 336969},
#  {'srcaddr': '104.3.190.249',
#   'srcport': 10077,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 14,
#   'packets': 421,
#   'bytes': 649119},
#  {'srcaddr': '40.37.236.2',
#   'srcport': 61825,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 6,
#   'packets': 379,
#   'bytes': 759135},
#  {'srcaddr': '129.3.222.165',
#   'srcport': 21553,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 1,
#   'packets': 272,
#   'bytes': 47096},
#  {'srcaddr': '155.55.219.231',
#   'srcport': 8312,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 4,
#   'packets': 480,
#   'bytes': 556269},
#  {'srcaddr': '69.230.207.45',
#   'srcport': 5368,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 21,
#   'packets': 384,
#   'bytes': 677723},
#  {'srcaddr': '34.37.229.133',
#   'srcport': 3543,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 14,
#   'packets': 478,
#   'bytes': 686724},
#  {'srcaddr': '15.219.228.128',
#   'srcport': 2441,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 12,
#   'packets': 233,
#   'bytes': 752418},
#  {'srcaddr': '112.37.132.2',
#   'srcport': 50189,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 7,
#   'packets': 14,
#   'bytes': 155646},
#  {'srcaddr': '73.29.64.166',
#   'srcport': 3278,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 1,
#   'packets': 385,
#   'bytes': 892588},
#  {'srcaddr': '248.120.24.55',
#   'srcport': 22299,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 24,
#   'packets': 153,
#   'bytes': 288703},
#  {'srcaddr': '177.98.115.208',
#   'srcport': 31433,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 19,
#   'packets': 355,
#   'bytes': 96123},
#  {'srcaddr': '72.41.66.125',
#   'srcport': 6666,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 3,
#   'packets': 41,
#   'bytes': 55914},
#  {'srcaddr': '58.212.187.241',
#   'srcport': 28617,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 3,
#   'packets': 174,
#   'bytes': 95428},
#  {'srcaddr': '151.213.32.22',
#   'srcport': 59656,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 16,
#   'packets': 402,
#   'bytes': 343569},
#  {'srcaddr': '192.220.194.197',
#   'srcport': 64936,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 30,
#   'packets': 75,
#   'bytes': 37396},
#  {'srcaddr': '172.86.174.190',
#   'srcport': 1951,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 18,
#   'packets': 0,
#   'bytes': 199958},
#  {'srcaddr': '187.143.217.191',
#   'srcport': 19727,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 26,
#   'packets': 120,
#   'bytes': 347146},
#  {'srcaddr': '103.158.177.147',
#   'srcport': 45768,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 11,
#   'packets': 406,
#   'bytes': 151951},
#  {'srcaddr': '167.27.213.217',
#   'srcport': 23953,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 20,
#   'packets': 385,
#   'bytes': 83885},
#  {'srcaddr': '112.35.122.82',
#   'srcport': 34089,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 4,
#   'packets': 206,
#   'bytes': 35966},
#  {'srcaddr': '164.55.115.189',
#   'srcport': 58898,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 25,
#   'packets': 437,
#   'bytes': 252909},
#  {'srcaddr': '245.13.90.94',
#   'srcport': 59520,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 29,
#   'packets': 63,
#   'bytes': 290715},
#  {'srcaddr': '189.99.153.249',
#   'srcport': 42777,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 1,
#   'packets': 10,
#   'bytes': 196073},
#  {'srcaddr': '149.211.169.107',
#   'srcport': 12475,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 19,
#   'packets': 456,
#   'bytes': 744784},
#  {'srcaddr': '153.127.235.22',
#   'srcport': 14661,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 5,
#   'packets': 445,
#   'bytes': 536203},
#  {'srcaddr': '104.141.30.134',
#   'srcport': 18441,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 20,
#   'packets': 182,
#   'bytes': 815709},
#  {'srcaddr': '70.68.82.90',
#   'srcport': 41862,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 19,
#   'packets': 331,
#   'bytes': 328325},
#  {'srcaddr': '6.112.66.88',
#   'srcport': 55445,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 26,
#   'packets': 215,
#   'bytes': 818538},
#  {'srcaddr': '192.17.169.72',
#   'srcport': 163,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 9,
#   'packets': 364,
#   'bytes': 714787},
#  {'srcaddr': '194.31.217.62',
#   'srcport': 18112,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 14,
#   'packets': 21,
#   'bytes': 80823},
#  {'srcaddr': '7.157.71.235',
#   'srcport': 26382,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 10,
#   'packets': 122,
#   'bytes': 989369},
#  {'srcaddr': '53.18.191.66',
#   'srcport': 43637,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 13,
#   'packets': 269,
#   'bytes': 867890},
#  {'srcaddr': '41.168.176.253',
#   'srcport': 21399,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 28,
#   'packets': 120,
#   'bytes': 705031},
#  {'srcaddr': '240.238.22.123',
#   'srcport': 30076,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 2,
#   'packets': 344,
#   'bytes': 751383},
#  {'srcaddr': '46.21.54.61',
#   'srcport': 42874,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 30,
#   'packets': 179,
#   'bytes': 424892},
#  {'srcaddr': '219.34.189.167',
#   'srcport': 3670,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 14,
#   'packets': 244,
#   'bytes': 710080},
#  {'srcaddr': '215.170.70.193',
#   'srcport': 26442,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 23,
#   'packets': 161,
#   'bytes': 443857},
#  {'srcaddr': '182.178.211.186',
#   'srcport': 14534,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 28,
#   'packets': 295,
#   'bytes': 782921},
#  {'srcaddr': '67.247.162.161',
#   'srcport': 35488,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 5,
#   'packets': 41,
#   'bytes': 367439},
#  {'srcaddr': '25.99.45.134',
#   'srcport': 27466,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 20,
#   'packets': 71,
#   'bytes': 696889},
#  {'srcaddr': '94.134.87.181',
#   'srcport': 42453,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 13,
#   'packets': 42,
#   'bytes': 687928},
#  {'srcaddr': '94.83.196.17',
#   'srcport': 43232,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 7,
#   'packets': 378,
#   'bytes': 704872},
#  {'srcaddr': '218.44.152.246',
#   'srcport': 56826,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 23,
#   'packets': 305,
#   'bytes': 964695},
#  {'srcaddr': '151.156.175.183',
#   'srcport': 1960,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 21,
#   'packets': 105,
#   'bytes': 55306},
#  {'srcaddr': '181.97.103.171',
#   'srcport': 16440,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 0,
#   'packets': 162,
#   'bytes': 882208},
#  {'srcaddr': '216.174.42.151',
#   'srcport': 63585,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 27,
#   'packets': 289,
#   'bytes': 616789},
#  {'srcaddr': '205.183.39.238',
#   'srcport': 44700,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 26,
#   'packets': 337,
#   'bytes': 716460},
#  {'srcaddr': '182.115.130.220',
#   'srcport': 39528,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 15,
#   'packets': 393,
#   'bytes': 305135},
#  {'srcaddr': '196.85.245.21',
#   'srcport': 27255,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 24,
#   'packets': 293,
#   'bytes': 206470},
#  {'srcaddr': '75.179.161.48',
#   'srcport': 60984,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 10,
#   'packets': 98,
#   'bytes': 215717},
#  {'srcaddr': '98.38.118.59',
#   'srcport': 12973,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 4,
#   'packets': 386,
#   'bytes': 535150},
#  {'srcaddr': '176.114.111.24',
#   'srcport': 42967,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 14,
#   'packets': 69,
#   'bytes': 416230},
#  {'srcaddr': '40.67.201.152',
#   'srcport': 59126,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 11,
#   'packets': 474,
#   'bytes': 424587},
#  {'srcaddr': '131.89.16.104',
#   'srcport': 17259,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 6,
#   'packets': 31,
#   'bytes': 640064},
#  {'srcaddr': '140.201.226.117',
#   'srcport': 27281,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 7,
#   'packets': 168,
#   'bytes': 813184},
#  {'srcaddr': '197.11.224.17',
#   'srcport': 63595,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 27,
#   'packets': 203,
#   'bytes': 989894},
#  {'srcaddr': '169.24.162.50',
#   'srcport': 46517,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 7,
#   'packets': 162,
#   'bytes': 786342},
#  {'srcaddr': '94.215.61.41',
#   'srcport': 7961,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 12,
#   'packets': 21,
#   'bytes': 23406},
#  {'srcaddr': '25.196.96.208',
#   'srcport': 56266,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 22,
#   'packets': 465,
#   'bytes': 186407},
#  {'srcaddr': '35.84.56.182',
#   'srcport': 15314,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 30,
#   'packets': 245,
#   'bytes': 391610},
#  {'srcaddr': '156.89.106.186',
#   'srcport': 55410,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 4,
#   'packets': 382,
#   'bytes': 369414},
#  {'srcaddr': '178.173.224.183',
#   'srcport': 45158,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 22,
#   'packets': 186,
#   'bytes': 656270},
#  {'srcaddr': '145.183.183.177',
#   'srcport': 45713,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 15,
#   'packets': 87,
#   'bytes': 839445},
#  {'srcaddr': '84.185.242.237',
#   'srcport': 23340,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 9,
#   'packets': 374,
#   'bytes': 839914},
#  {'srcaddr': '249.20.216.215',
#   'srcport': 43524,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 28,
#   'packets': 63,
#   'bytes': 385793},
#  {'srcaddr': '14.148.186.85',
#   'srcport': 41782,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 19,
#   'packets': 364,
#   'bytes': 153423},
#  {'srcaddr': '12.136.21.34',
#   'srcport': 16322,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 9,
#   'packets': 235,
#   'bytes': 368081},
#  {'srcaddr': '66.163.255.252',
#   'srcport': 38896,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 26,
#   'packets': 319,
#   'bytes': 964626},
#  {'srcaddr': '151.175.88.57',
#   'srcport': 60317,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 29,
#   'packets': 120,
#   'bytes': 556755},
#  {'srcaddr': '87.61.96.93',
#   'srcport': 10930,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 21,
#   'packets': 30,
#   'bytes': 899890},
#  {'srcaddr': '212.29.190.81',
#   'srcport': 46223,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 20,
#   'packets': 153,
#   'bytes': 436652},
#  {'srcaddr': '109.246.54.211',
#   'srcport': 32468,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 18,
#   'packets': 154,
#   'bytes': 146388},
#  {'srcaddr': '22.89.167.149',
#   'srcport': 44257,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 7,
#   'packets': 60,
#   'bytes': 159492},
#  {'srcaddr': '176.118.118.73',
#   'srcport': 4354,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 19,
#   'packets': 250,
#   'bytes': 169294},
#  {'srcaddr': '90.193.98.162',
#   'srcport': 22288,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 12,
#   'packets': 93,
#   'bytes': 252185},
#  {'srcaddr': '5.28.164.68',
#   'srcport': 32862,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 5,
#   'packets': 14,
#   'bytes': 546205},
#  {'srcaddr': '139.198.165.48',
#   'srcport': 40858,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 14,
#   'packets': 236,
#   'bytes': 781787},
#  {'srcaddr': '198.55.251.117',
#   'srcport': 29063,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 8,
#   'packets': 186,
#   'bytes': 465031},
#  {'srcaddr': '128.182.37.134',
#   'srcport': 49006,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 9,
#   'packets': 252,
#   'bytes': 23287},
#  {'srcaddr': '26.59.127.33',
#   'srcport': 64778,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 13,
#   'packets': 364,
#   'bytes': 758210},
#  {'srcaddr': '126.171.83.64',
#   'srcport': 43079,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 2,
#   'packets': 223,
#   'bytes': 427699},
#  {'srcaddr': '201.76.83.183',
#   'srcport': 36761,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 29,
#   'packets': 147,
#   'bytes': 761130},
#  {'srcaddr': '3.28.20.68',
#   'srcport': 51438,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 18,
#   'packets': 310,
#   'bytes': 5970},
#  {'srcaddr': '13.119.105.132',
#   'srcport': 28401,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 22,
#   'packets': 63,
#   'bytes': 415001},
#  {'srcaddr': '161.219.187.174',
#   'srcport': 47769,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 12,
#   'packets': 139,
#   'bytes': 785996},
#  {'srcaddr': '220.225.44.103',
#   'srcport': 29265,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 18,
#   'packets': 13,
#   'bytes': 510434},
#  {'srcaddr': '192.172.163.232',
#   'srcport': 31772,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 27,
#   'packets': 48,
#   'bytes': 343413},
#  {'srcaddr': '78.195.128.48',
#   'srcport': 40593,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 11,
#   'packets': 266,
#   'bytes': 273300},
#  {'srcaddr': '191.148.95.96',
#   'srcport': 44895,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 8,
#   'packets': 267,
#   'bytes': 599626},
#  {'srcaddr': '74.172.4.34',
#   'srcport': 15993,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 5,
#   'packets': 190,
#   'bytes': 349862},
#  {'srcaddr': '221.214.200.178',
#   'srcport': 51769,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 29,
#   'packets': 351,
#   'bytes': 229828},
#  {'srcaddr': '215.109.233.46',
#   'srcport': 27361,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 29,
#   'packets': 203,
#   'bytes': 445854},
#  {'srcaddr': '186.9.12.110',
#   'srcport': 32036,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 11,
#   'packets': 369,
#   'bytes': 681502},
#  {'srcaddr': '115.113.4.156',
#   'srcport': 22743,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 19,
#   'packets': 11,
#   'bytes': 809193},
#  {'srcaddr': '123.204.215.202',
#   'srcport': 5476,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 3,
#   'packets': 113,
#   'bytes': 34095},
#  {'srcaddr': '41.107.184.68',
#   'srcport': 8470,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 0,
#   'packets': 289,
#   'bytes': 873246},
#  {'srcaddr': '174.43.40.173',
#   'srcport': 48516,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 1,
#   'packets': 177,
#   'bytes': 218185},
#  {'srcaddr': '219.49.172.209',
#   'srcport': 24780,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 12,
#   'packets': 479,
#   'bytes': 911926},
#  {'srcaddr': '57.206.37.97',
#   'srcport': 28292,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 28,
#   'packets': 398,
#   'bytes': 55708},
#  {'srcaddr': '32.57.251.191',
#   'srcport': 20867,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 12,
#   'packets': 96,
#   'bytes': 355946},
#  {'srcaddr': '244.187.100.98',
#   'srcport': 1655,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 27,
#   'packets': 55,
#   'bytes': 680605},
#  {'srcaddr': '165.115.131.48',
#   'srcport': 28920,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 7,
#   'packets': 337,
#   'bytes': 891111},
#  {'srcaddr': '67.24.19.8',
#   'srcport': 59100,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 20,
#   'packets': 438,
#   'bytes': 651592},
#  {'srcaddr': '166.127.16.149',
#   'srcport': 16775,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 8,
#   'packets': 326,
#   'bytes': 603395},
#  {'srcaddr': '75.41.7.126',
#   'srcport': 51613,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 25,
#   'packets': 189,
#   'bytes': 449825},
#  {'srcaddr': '183.2.26.15',
#   'srcport': 21491,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 18,
#   'packets': 18,
#   'bytes': 160161},
#  {'srcaddr': '105.114.38.97',
#   'srcport': 19214,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 7,
#   'packets': 424,
#   'bytes': 844847},
#  {'srcaddr': '14.120.202.1',
#   'srcport': 4747,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 15,
#   'packets': 281,
#   'bytes': 425535},
#  {'srcaddr': '163.207.133.149',
#   'srcport': 29178,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 30,
#   'packets': 89,
#   'bytes': 223835},
#  {'srcaddr': '221.218.59.138',
#   'srcport': 44806,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 18,
#   'packets': 334,
#   'bytes': 577583},
#  {'srcaddr': '15.229.0.154',
#   'srcport': 36705,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 26,
#   'packets': 408,
#   'bytes': 532358},
#  {'srcaddr': '27.5.79.16',
#   'srcport': 17930,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 4,
#   'packets': 293,
#   'bytes': 812685},
#  {'srcaddr': '249.229.156.38',
#   'srcport': 41881,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 2,
#   'packets': 48,
#   'bytes': 768821},
#  {'srcaddr': '14.245.115.11',
#   'srcport': 30604,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 2,
#   'packets': 382,
#   'bytes': 382850},
#  {'srcaddr': '40.21.117.224',
#   'srcport': 37717,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 17,
#   'packets': 318,
#   'bytes': 686141},
#  {'srcaddr': '41.213.44.135',
#   'srcport': 45908,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 30,
#   'packets': 214,
#   'bytes': 404663},
#  {'srcaddr': '85.206.108.213',
#   'srcport': 172,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 13,
#   'packets': 90,
#   'bytes': 845940},
#  {'srcaddr': '18.186.211.212',
#   'srcport': 21764,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 7,
#   'packets': 126,
#   'bytes': 370021},
#  {'srcaddr': '105.163.12.32',
#   'srcport': 64693,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 8,
#   'packets': 249,
#   'bytes': 222300},
#  {'srcaddr': '229.63.236.81',
#   'srcport': 44916,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 17,
#   'packets': 320,
#   'bytes': 483076},
#  {'srcaddr': '249.125.129.48',
#   'srcport': 45076,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 29,
#   'packets': 142,
#   'bytes': 680891},
#  {'srcaddr': '166.139.165.223',
#   'srcport': 36006,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 24,
#   'packets': 162,
#   'bytes': 841839},
#  {'srcaddr': '6.255.187.90',
#   'srcport': 62887,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 27,
#   'packets': 143,
#   'bytes': 869837},
#  {'srcaddr': '122.231.33.14',
#   'srcport': 59178,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 5,
#   'packets': 168,
#   'bytes': 83302},
#  {'srcaddr': '101.146.32.132',
#   'srcport': 6854,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 5,
#   'packets': 218,
#   'bytes': 364465},
#  {'srcaddr': '94.243.93.202',
#   'srcport': 38669,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 2,
#   'packets': 196,
#   'bytes': 188232},
#  {'srcaddr': '181.250.20.173',
#   'srcport': 24436,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 2,
#   'packets': 382,
#   'bytes': 306473},
#  {'srcaddr': '157.175.71.67',
#   'srcport': 1332,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 24,
#   'packets': 487,
#   'bytes': 107579},
#  {'srcaddr': '38.129.78.39',
#   'srcport': 64211,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 25,
#   'packets': 56,
#   'bytes': 242295},
#  {'srcaddr': '241.58.41.2',
#   'srcport': 4603,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 1,
#   'packets': 225,
#   'bytes': 290677},
#  {'srcaddr': '164.164.46.98',
#   'srcport': 14325,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 25,
#   'packets': 256,
#   'bytes': 597199},
#  {'srcaddr': '175.160.125.117',
#   'srcport': 39541,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 25,
#   'packets': 339,
#   'bytes': 38970},
#  {'srcaddr': '145.91.232.113',
#   'srcport': 64156,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 26,
#   'packets': 273,
#   'bytes': 225303},
# ...
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 25,
#   'packets': 492,
#   'bytes': 422378},
#  {'srcaddr': '248.99.129.220',
#   'srcport': 51846,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 3,
#   'packets': 142,
#   'bytes': 855521},
#  {'srcaddr': '154.46.119.112',
#   'srcport': 7454,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 4,
#   'packets': 286,
#   'bytes': 855179},
#  {'srcaddr': '28.77.28.22',
#   'srcport': 26707,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 2,
#   'packets': 196,
#   'bytes': 149244},
#  {'srcaddr': '91.73.125.57',
#   'srcport': 39253,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 7,
#   'packets': 232,
#   'bytes': 854313},
#  {'srcaddr': '191.130.241.142',
#   'srcport': 23570,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 24,
#   'packets': 62,
#   'bytes': 306742},
#  {'srcaddr': '245.184.121.58',
#   'srcport': 64768,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 23,
#   'packets': 167,
#   'bytes': 629199},
#  {'srcaddr': '191.201.112.8',
#   'srcport': 62460,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 2,
#   'packets': 479,
#   'bytes': 93198},
#  {'srcaddr': '134.2.85.196',
#   'srcport': 49808,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 10,
#   'packets': 233,
#   'bytes': 364118},
#  {'srcaddr': '168.143.184.33',
#   'srcport': 40444,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 1,
#   'packets': 72,
#   'bytes': 329437},
#  {'srcaddr': '83.33.163.181',
#   'srcport': 46712,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 1,
#   'packets': 306,
#   'bytes': 130172},
#  {'srcaddr': '70.27.156.240',
#   'srcport': 54445,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 22,
#   'packets': 286,
#   'bytes': 188284},
#  {'srcaddr': '172.196.55.167',
#   'srcport': 13520,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 15,
#   'packets': 226,
#   'bytes': 869296},
#  {'srcaddr': '73.158.163.74',
#   'srcport': 12039,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 0,
#   'packets': 75,
#   'bytes': 862741},
#  {'srcaddr': '12.41.165.1',
#   'srcport': 61264,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 17,
#   'packets': 387,
#   'bytes': 384386},
#  {'srcaddr': '62.79.85.149',
#   'srcport': 60296,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 21,
#   'packets': 439,
#   'bytes': 20146},
#  {'srcaddr': '195.77.253.17',
#   'srcport': 47986,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 26,
#   'packets': 198,
#   'bytes': 441460},
#  {'srcaddr': '64.208.198.227',
#   'srcport': 56740,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 11,
#   'packets': 285,
#   'bytes': 293634},
#  {'srcaddr': '239.62.209.2',
#   'srcport': 50016,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 21,
#   'packets': 182,
#   'bytes': 602137},
#  {'srcaddr': '59.144.91.53',
#   'srcport': 15847,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 13,
#   'packets': 139,
#   'bytes': 801375},
#  {'srcaddr': '25.98.203.128',
#   'srcport': 31897,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 13,
#   'packets': 138,
#   'bytes': 755898},
#  {'srcaddr': '26.159.96.164',
#   'srcport': 44214,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 28,
#   'packets': 203,
#   'bytes': 960699},
#  {'srcaddr': '87.79.24.230',
#   'srcport': 7191,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 26,
#   'packets': 494,
#   'bytes': 243729},
#  {'srcaddr': '132.22.217.143',
#   'srcport': 13518,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 20,
#   'packets': 115,
#   'bytes': 625114},
#  {'srcaddr': '34.200.161.29',
#   'srcport': 52981,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 3,
#   'packets': 65,
#   'bytes': 631108},
#  {'srcaddr': '47.65.220.253',
#   'srcport': 28909,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 25,
#   'packets': 307,
#   'bytes': 655921},
#  {'srcaddr': '142.56.193.21',
#   'srcport': 45322,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 29,
#   'packets': 92,
#   'bytes': 598552},
#  {'srcaddr': '67.239.14.141',
#   'srcport': 60589,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 30,
#   'packets': 75,
#   'bytes': 311711},
#  {'srcaddr': '138.87.248.5',
#   'srcport': 9472,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 7,
#   'packets': 144,
#   'bytes': 787406},
#  {'srcaddr': '35.147.236.143',
#   'srcport': 51189,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 14,
#   'packets': 494,
#   'bytes': 927274},
#  {'srcaddr': '4.178.15.134',
#   'srcport': 43503,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 0,
#   'packets': 15,
#   'bytes': 555161},
#  {'srcaddr': '180.93.132.190',
#   'srcport': 54519,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 26,
#   'packets': 189,
#   'bytes': 455293},
#  {'srcaddr': '14.163.224.210',
#   'srcport': 47772,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 29,
#   'packets': 410,
#   'bytes': 765581},
#  {'srcaddr': '153.173.15.208',
#   'srcport': 438,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 12,
#   'packets': 474,
#   'bytes': 57954},
#  {'srcaddr': '163.253.74.121',
#   'srcport': 64681,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 4,
#   'packets': 150,
#   'bytes': 566678},
#  {'srcaddr': '66.201.247.72',
#   'srcport': 41343,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 19,
#   'packets': 308,
#   'bytes': 548184},
#  {'srcaddr': '97.149.39.188',
#   'srcport': 38702,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 1,
#   'packets': 276,
#   'bytes': 410908},
#  {'srcaddr': '206.214.205.60',
#   'srcport': 3725,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 20,
#   'packets': 342,
#   'bytes': 656848},
#  {'srcaddr': '114.46.30.192',
#   'srcport': 24389,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 19,
#   'packets': 254,
#   'bytes': 144142},
#  {'srcaddr': '1.175.56.154',
#   'srcport': 24024,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 29,
#   'packets': 267,
#   'bytes': 781409},
#  {'srcaddr': '55.190.185.76',
#   'srcport': 6557,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 24,
#   'packets': 8,
#   'bytes': 239480},
#  {'srcaddr': '232.225.251.248',
#   'srcport': 65446,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 0,
#   'packets': 420,
#   'bytes': 302876},
#  {'srcaddr': '12.1.39.39',
#   'srcport': 23234,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 9,
#   'packets': 393,
#   'bytes': 513511},
#  {'srcaddr': '157.55.96.80',
#   'srcport': 7207,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 18,
#   'packets': 212,
#   'bytes': 621365},
#  {'srcaddr': '210.16.101.8',
#   'srcport': 19348,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 15,
#   'packets': 325,
#   'bytes': 12910},
#  {'srcaddr': '181.110.56.147',
#   'srcport': 19779,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 23,
#   'packets': 189,
#   'bytes': 701336},
#  {'srcaddr': '156.124.71.109',
#   'srcport': 35731,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 7,
#   'packets': 284,
#   'bytes': 291592},
#  {'srcaddr': '17.68.227.117',
#   'srcport': 26871,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 29,
#   'packets': 138,
#   'bytes': 281473},
#  {'srcaddr': '160.207.68.144',
#   'srcport': 22510,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 10,
#   'packets': 74,
#   'bytes': 306629},
#  {'srcaddr': '128.208.81.111',
#   'srcport': 3605,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 10,
#   'packets': 15,
#   'bytes': 356208},
#  {'srcaddr': '148.219.81.253',
#   'srcport': 45785,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 30,
#   'packets': 448,
#   'bytes': 111989},
#  {'srcaddr': '174.209.95.250',
#   'srcport': 14619,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 6,
#   'packets': 428,
#   'bytes': 978589},
#  {'srcaddr': '14.140.27.221',
#   'srcport': 42284,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 22,
#   'packets': 160,
#   'bytes': 256416},
#  {'srcaddr': '70.146.181.235',
#   'srcport': 39122,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 5,
#   'packets': 315,
#   'bytes': 781612},
#  {'srcaddr': '177.217.132.9',
#   'srcport': 57841,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 4,
#   'packets': 386,
#   'bytes': 521198},
#  {'srcaddr': '190.148.52.34',
#   'srcport': 35154,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 29,
#   'packets': 80,
#   'bytes': 969714},
#  {'srcaddr': '153.107.165.1',
#   'srcport': 56351,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 21,
#   'packets': 6,
#   'bytes': 428461},
#  {'srcaddr': '181.156.81.22',
#   'srcport': 60198,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 25,
#   'packets': 366,
#   'bytes': 574427},
#  {'srcaddr': '123.160.162.122',
#   'srcport': 12652,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 9,
#   'packets': 482,
#   'bytes': 842292},
#  {'srcaddr': '22.224.137.170',
#   'srcport': 32661,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 7,
#   'packets': 345,
#   'bytes': 620216},
#  {'srcaddr': '194.139.200.11',
#   'srcport': 64436,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 1,
#   'packets': 343,
#   'bytes': 576660},
#  {'srcaddr': '94.84.14.192',
#   'srcport': 64369,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 6,
#   'packets': 24,
#   'bytes': 216102},
#  {'srcaddr': '220.112.166.227',
#   'srcport': 37904,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 27,
#   'packets': 452,
#   'bytes': 165298},
#  {'srcaddr': '209.62.120.87',
#   'srcport': 3636,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 9,
#   'packets': 293,
#   'bytes': 377253},
#  {'srcaddr': '145.157.28.216',
#   'srcport': 19040,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 30,
#   'packets': 5,
#   'bytes': 926147},
#  {'srcaddr': '245.0.196.203',
#   'srcport': 2537,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 4,
#   'packets': 445,
#   'bytes': 213848},
#  {'srcaddr': '120.135.90.91',
#   'srcport': 59263,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 6,
#   'packets': 293,
#   'bytes': 662112},
#  {'srcaddr': '51.127.208.36',
#   'srcport': 40371,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 14,
#   'packets': 281,
#   'bytes': 390708},
#  {'srcaddr': '16.87.193.5',
#   'srcport': 79,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 19,
#   'packets': 63,
#   'bytes': 106045},
#  {'srcaddr': '192.62.77.141',
#   'srcport': 12571,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 26,
#   'packets': 423,
#   'bytes': 776133},
#  {'srcaddr': '35.51.42.187',
#   'srcport': 42494,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 4,
#   'packets': 24,
#   'bytes': 501266},
#  {'srcaddr': '116.89.247.144',
#   'srcport': 35400,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 12,
#   'packets': 22,
#   'bytes': 597672},
#  {'srcaddr': '232.112.174.218',
#   'srcport': 27747,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 5,
#   'packets': 168,
#   'bytes': 777649},
#  {'srcaddr': '78.119.79.72',
#   'srcport': 2634,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 14,
#   'packets': 448,
#   'bytes': 493153},
#  {'srcaddr': '113.78.160.179',
#   'srcport': 10254,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 23,
#   'packets': 2,
#   'bytes': 662803},
#  {'srcaddr': '103.153.175.79',
#   'srcport': 36126,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 0,
#   'packets': 371,
#   'bytes': 90437},
#  {'srcaddr': '110.76.40.63',
#   'srcport': 43176,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 9,
#   'packets': 261,
#   'bytes': 617988},
#  {'srcaddr': '234.153.13.83',
#   'srcport': 7521,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 18,
#   'packets': 183,
#   'bytes': 459396},
#  {'srcaddr': '168.159.48.109',
#   'srcport': 57594,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 17,
#   'packets': 495,
#   'bytes': 145823},
#  {'srcaddr': '55.66.126.99',
#   'srcport': 51422,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 28,
#   'packets': 204,
#   'bytes': 862648},
#  {'srcaddr': '162.167.88.44',
#   'srcport': 3652,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 28,
#   'packets': 425,
#   'bytes': 584653},
#  {'srcaddr': '103.151.247.95',
#   'srcport': 53557,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 22,
#   'packets': 396,
#   'bytes': 882802},
#  {'srcaddr': '166.114.112.131',
#   'srcport': 52521,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 0,
#   'packets': 470,
#   'bytes': 599104},
#  {'srcaddr': '202.118.112.232',
#   'srcport': 57044,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 7,
#   'packets': 372,
#   'bytes': 902376},
#  {'srcaddr': '63.189.94.177',
#   'srcport': 53000,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 0,
#   'packets': 336,
#   'bytes': 473745},
#  {'srcaddr': '179.202.199.110',
#   'srcport': 56323,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 25,
#   'packets': 336,
#   'bytes': 562500},
#  {'srcaddr': '157.181.213.71',
#   'srcport': 34344,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 11,
#   'packets': 69,
#   'bytes': 884824},
#  {'srcaddr': '7.244.166.62',
#   'srcport': 39360,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 14,
#   'packets': 81,
#   'bytes': 681199},
#  {'srcaddr': '174.215.165.112',
#   'srcport': 23990,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 14,
#   'packets': 195,
#   'bytes': 92208},
#  {'srcaddr': '110.92.121.6',
#   'srcport': 42842,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 26,
#   'packets': 162,
#   'bytes': 143508},
#  {'srcaddr': '245.162.165.199',
#   'srcport': 9144,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 16,
#   'packets': 15,
#   'bytes': 443583},
#  ...]

# %%
new_record.sort(key=lambda k: (k.get('srcaddr', 0)))

# %%
new_record
# Out:
# [{'srcaddr': '0.0.11.12',
#   'srcport': 51803,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 6,
#   'packets': 69,
#   'bytes': 798498},
#  {'srcaddr': '0.0.113.223',
#   'srcport': 11791,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 3,
#   'packets': 338,
#   'bytes': 350258},
#  {'srcaddr': '0.0.118.69',
#   'srcport': 54193,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 27,
#   'packets': 247,
#   'bytes': 704902},
#  {'srcaddr': '0.0.13.142',
#   'srcport': 64096,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 6,
#   'packets': 201,
#   'bytes': 732430},
#  {'srcaddr': '0.0.144.93',
#   'srcport': 19912,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 21,
#   'packets': 391,
#   'bytes': 137327},
#  {'srcaddr': '0.0.152.98',
#   'srcport': 4773,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 22,
#   'packets': 359,
#   'bytes': 778786},
#  {'srcaddr': '0.0.155.12',
#   'srcport': 24070,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 7,
#   'packets': 34,
#   'bytes': 786399},
#  {'srcaddr': '0.0.171.50',
#   'srcport': 25130,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 21,
#   'packets': 415,
#   'bytes': 791562},
#  {'srcaddr': '0.0.180.245',
#   'srcport': 12806,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 9,
#   'packets': 250,
#   'bytes': 388056},
#  {'srcaddr': '0.0.183.190',
#   'srcport': 51993,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 18,
#   'packets': 220,
#   'bytes': 927882},
#  {'srcaddr': '0.0.199.16',
#   'srcport': 18465,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 15,
#   'packets': 385,
#   'bytes': 355},
#  {'srcaddr': '0.0.224.129',
#   'srcport': 29698,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 3,
#   'packets': 34,
#   'bytes': 413155},
#  {'srcaddr': '0.0.231.161',
#   'srcport': 45563,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 21,
#   'packets': 141,
#   'bytes': 850735},
#  {'srcaddr': '0.0.236.213',
#   'srcport': 28341,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 30,
#   'packets': 65,
#   'bytes': 568731},
#  {'srcaddr': '0.0.34.167',
#   'srcport': 37727,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 23,
#   'packets': 500,
#   'bytes': 835713},
#  {'srcaddr': '0.0.4.184',
#   'srcport': 43324,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 9,
#   'packets': 328,
#   'bytes': 156946},
#  {'srcaddr': '0.0.42.26',
#   'srcport': 29983,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 16,
#   'packets': 445,
#   'bytes': 88904},
#  {'srcaddr': '0.0.56.227',
#   'srcport': 3402,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 20,
#   'packets': 411,
#   'bytes': 51276},
#  {'srcaddr': '0.0.63.216',
#   'srcport': 42215,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 21,
#   'packets': 223,
#   'bytes': 115913},
#  {'srcaddr': '0.0.68.114',
#   'srcport': 25060,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 25,
#   'packets': 124,
#   'bytes': 237022},
#  {'srcaddr': '0.0.72.208',
#   'srcport': 2309,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 7,
#   'packets': 444,
#   'bytes': 366505},
#  {'srcaddr': '0.0.83.54',
#   'srcport': 95,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 13,
#   'packets': 289,
#   'bytes': 210295},
#  {'srcaddr': '0.1.100.171',
#   'srcport': 51657,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 12,
#   'packets': 223,
#   'bytes': 68856},
#  {'srcaddr': '0.1.142.198',
#   'srcport': 24592,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 0,
#   'packets': 40,
#   'bytes': 632674},
#  {'srcaddr': '0.1.144.86',
#   'srcport': 27361,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 2,
#   'packets': 206,
#   'bytes': 87595},
#  {'srcaddr': '0.1.150.155',
#   'srcport': 3938,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 23,
#   'packets': 380,
#   'bytes': 125480},
#  {'srcaddr': '0.1.177.238',
#   'srcport': 22917,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 7,
#   'packets': 458,
#   'bytes': 11111},
#  {'srcaddr': '0.1.188.15',
#   'srcport': 44831,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 25,
#   'packets': 190,
#   'bytes': 746161},
#  {'srcaddr': '0.1.189.100',
#   'srcport': 52587,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 19,
#   'packets': 307,
#   'bytes': 533730},
#  {'srcaddr': '0.1.205.187',
#   'srcport': 21529,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 2,
#   'packets': 21,
#   'bytes': 312988},
#  {'srcaddr': '0.1.222.184',
#   'srcport': 62545,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 27,
#   'packets': 248,
#   'bytes': 464726},
#  {'srcaddr': '0.1.240.67',
#   'srcport': 1020,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 30,
#   'packets': 214,
#   'bytes': 868303},
#  {'srcaddr': '0.1.27.142',
#   'srcport': 46269,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 2,
#   'packets': 334,
#   'bytes': 865706},
#  {'srcaddr': '0.1.41.190',
#   'srcport': 700,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 30,
#   'packets': 478,
#   'bytes': 397927},
#  {'srcaddr': '0.1.5.21',
#   'srcport': 43276,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 28,
#   'packets': 249,
#   'bytes': 582131},
#  {'srcaddr': '0.1.74.83',
#   'srcport': 895,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 26,
#   'packets': 315,
#   'bytes': 225348},
#  {'srcaddr': '0.1.86.199',
#   'srcport': 51758,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 28,
#   'packets': 290,
#   'bytes': 121575},
#  {'srcaddr': '0.10.105.5',
#   'srcport': 15783,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 10,
#   'packets': 45,
#   'bytes': 557133},
#  {'srcaddr': '0.10.166.131',
#   'srcport': 15589,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 3,
#   'packets': 88,
#   'bytes': 217708},
#  {'srcaddr': '0.10.59.10',
#   'srcport': 50381,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 2,
#   'packets': 331,
#   'bytes': 128196},
#  {'srcaddr': '0.10.65.185',
#   'srcport': 7164,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 8,
#   'packets': 384,
#   'bytes': 69284},
#  {'srcaddr': '0.10.65.70',
#   'srcport': 50869,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 9,
#   'packets': 453,
#   'bytes': 526999},
#  {'srcaddr': '0.10.81.56',
#   'srcport': 41717,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 28,
#   'packets': 353,
#   'bytes': 782424},
#  {'srcaddr': '0.100.103.209',
#   'srcport': 61601,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 9,
#   'packets': 480,
#   'bytes': 137610},
#  {'srcaddr': '0.100.131.96',
#   'srcport': 19600,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 24,
#   'packets': 206,
#   'bytes': 991616},
#  {'srcaddr': '0.100.140.96',
#   'srcport': 53442,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 23,
#   'packets': 285,
#   'bytes': 897957},
#  {'srcaddr': '0.100.142.76',
#   'srcport': 22334,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 6,
#   'packets': 66,
#   'bytes': 908886},
#  {'srcaddr': '0.100.158.177',
#   'srcport': 13039,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 27,
#   'packets': 408,
#   'bytes': 826957},
#  {'srcaddr': '0.100.192.232',
#   'srcport': 24202,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 27,
#   'packets': 216,
#   'bytes': 304315},
#  {'srcaddr': '0.100.23.123',
#   'srcport': 3080,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 18,
#   'packets': 493,
#   'bytes': 184449},
#  {'srcaddr': '0.100.235.18',
#   'srcport': 22581,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 25,
#   'packets': 226,
#   'bytes': 155150},
#  {'srcaddr': '0.100.237.86',
#   'srcport': 42438,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 17,
#   'packets': 436,
#   'bytes': 747412},
#  {'srcaddr': '0.100.52.241',
#   'srcport': 15830,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 26,
#   'packets': 210,
#   'bytes': 421049},
#  {'srcaddr': '0.100.55.130',
#   'srcport': 13665,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 23,
#   'packets': 19,
#   'bytes': 668492},
#  {'srcaddr': '0.100.7.108',
#   'srcport': 6679,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 26,
#   'packets': 457,
#   'bytes': 765353},
#  {'srcaddr': '0.100.97.134',
#   'srcport': 52912,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 24,
#   'packets': 229,
#   'bytes': 1720},
#  {'srcaddr': '0.101.114.77',
#   'srcport': 58194,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 5,
#   'packets': 463,
#   'bytes': 202383},
#  {'srcaddr': '0.101.12.17',
#   'srcport': 3724,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 10,
#   'packets': 171,
#   'bytes': 526946},
#  {'srcaddr': '0.101.122.171',
#   'srcport': 34789,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 8,
#   'packets': 88,
#   'bytes': 12518},
#  {'srcaddr': '0.101.126.171',
#   'srcport': 8247,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 6,
#   'packets': 140,
#   'bytes': 940801},
#  {'srcaddr': '0.101.154.175',
#   'srcport': 15960,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 10,
#   'packets': 252,
#   'bytes': 148043},
#  {'srcaddr': '0.101.185.39',
#   'srcport': 37203,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 26,
#   'packets': 232,
#   'bytes': 951992},
#  {'srcaddr': '0.101.189.223',
#   'srcport': 56327,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 29,
#   'packets': 178,
#   'bytes': 799885},
#  {'srcaddr': '0.101.195.22',
#   'srcport': 25177,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 30,
#   'packets': 128,
#   'bytes': 889220},
#  {'srcaddr': '0.101.207.252',
#   'srcport': 6300,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 9,
#   'packets': 224,
#   'bytes': 497273},
#  {'srcaddr': '0.101.222.129',
#   'srcport': 3779,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 15,
#   'packets': 412,
#   'bytes': 34377},
#  {'srcaddr': '0.101.233.33',
#   'srcport': 4233,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 27,
#   'packets': 471,
#   'bytes': 13466},
#  {'srcaddr': '0.101.235.1',
#   'srcport': 59896,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 30,
#   'packets': 257,
#   'bytes': 964019},
#  {'srcaddr': '0.101.252.255',
#   'srcport': 31418,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 25,
#   'packets': 273,
#   'bytes': 773923},
#  {'srcaddr': '0.101.47.62',
#   'srcport': 65385,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 28,
#   'packets': 442,
#   'bytes': 455998},
#  {'srcaddr': '0.101.48.155',
#   'srcport': 46264,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 6,
#   'packets': 114,
#   'bytes': 539377},
#  {'srcaddr': '0.102.133.4',
#   'srcport': 33333,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 20,
#   'packets': 148,
#   'bytes': 812419},
#  {'srcaddr': '0.102.160.34',
#   'srcport': 16054,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 3,
#   'packets': 82,
#   'bytes': 434703},
#  {'srcaddr': '0.102.172.42',
#   'srcport': 62823,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 26,
#   'packets': 167,
#   'bytes': 120501},
#  {'srcaddr': '0.102.177.115',
#   'srcport': 42071,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 0,
#   'packets': 61,
#   'bytes': 190934},
#  {'srcaddr': '0.102.191.45',
#   'srcport': 62454,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 21,
#   'packets': 126,
#   'bytes': 505663},
#  {'srcaddr': '0.102.206.125',
#   'srcport': 12400,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 7,
#   'packets': 105,
#   'bytes': 861837},
#  {'srcaddr': '0.102.214.139',
#   'srcport': 39500,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 27,
#   'packets': 331,
#   'bytes': 807001},
#  {'srcaddr': '0.102.217.73',
#   'srcport': 9774,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 15,
#   'packets': 67,
#   'bytes': 430787},
#  {'srcaddr': '0.102.223.131',
#   'srcport': 19986,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 17,
#   'packets': 300,
#   'bytes': 546024},
#  {'srcaddr': '0.102.227.118',
#   'srcport': 33728,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 10,
#   'packets': 369,
#   'bytes': 443217},
#  {'srcaddr': '0.102.23.114',
#   'srcport': 6057,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 25,
#   'packets': 299,
#   'bytes': 762430},
#  {'srcaddr': '0.102.237.184',
#   'srcport': 61370,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 10,
#   'packets': 382,
#   'bytes': 797625},
#  {'srcaddr': '0.102.240.181',
#   'srcport': 46420,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 27,
#   'packets': 258,
#   'bytes': 569202},
#  {'srcaddr': '0.102.27.194',
#   'srcport': 62075,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 24,
#   'packets': 272,
#   'bytes': 777382},
#  {'srcaddr': '0.102.29.204',
#   'srcport': 1912,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 1,
#   'packets': 203,
#   'bytes': 195885},
#  {'srcaddr': '0.102.31.21',
#   'srcport': 14878,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 14,
#   'packets': 237,
#   'bytes': 290252},
#  {'srcaddr': '0.102.53.10',
#   'srcport': 54486,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 10,
#   'packets': 67,
#   'bytes': 532244},
#  {'srcaddr': '0.102.7.123',
#   'srcport': 37470,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 1,
#   'packets': 498,
#   'bytes': 773452},
#  {'srcaddr': '0.103.110.97',
#   'srcport': 42179,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 11,
#   'packets': 85,
#   'bytes': 212778},
#  {'srcaddr': '0.103.135.249',
#   'srcport': 61604,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 15,
#   'packets': 231,
#   'bytes': 168703},
#  {'srcaddr': '0.103.138.233',
#   'srcport': 24021,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 27,
#   'packets': 193,
#   'bytes': 603822},
#  {'srcaddr': '0.103.153.156',
#   'srcport': 9184,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 20,
#   'packets': 97,
#   'bytes': 239447},
#  {'srcaddr': '0.103.157.62',
#   'srcport': 64643,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 27,
#   'packets': 196,
#   'bytes': 649924},
#  {'srcaddr': '0.103.17.155',
#   'srcport': 27237,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 6,
#   'packets': 319,
#   'bytes': 679899},
#  {'srcaddr': '0.103.178.101',
#   'srcport': 29636,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 4,
#   'packets': 244,
#   'bytes': 163549},
#  {'srcaddr': '0.103.39.255',
#   'srcport': 14792,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 2,
#   'packets': 161,
#   'bytes': 34152},
#  {'srcaddr': '0.103.46.143',
#   'srcport': 14548,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 8,
#   'packets': 267,
#   'bytes': 371007},
#  {'srcaddr': '0.103.55.71',
#   'srcport': 18533,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 21,
#   'packets': 441,
#   'bytes': 3997},
#  {'srcaddr': '0.103.59.104',
#   'srcport': 11155,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 19,
#   'packets': 91,
#   'bytes': 801108},
#  {'srcaddr': '0.103.90.180',
#   'srcport': 18636,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 3,
#   'packets': 447,
#   'bytes': 899407},
#  {'srcaddr': '0.103.99.221',
#   'srcport': 17190,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 22,
#   'packets': 137,
#   'bytes': 922994},
#  {'srcaddr': '0.104.115.33',
#   'srcport': 916,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 15,
#   'packets': 440,
#   'bytes': 344341},
#  {'srcaddr': '0.104.123.37',
#   'srcport': 2293,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 2,
#   'packets': 396,
#   'bytes': 110598},
#  {'srcaddr': '0.104.13.165',
#   'srcport': 46180,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 22,
#   'packets': 248,
#   'bytes': 618762},
#  {'srcaddr': '0.104.140.207',
#   'srcport': 40522,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 25,
#   'packets': 106,
#   'bytes': 67042},
#  {'srcaddr': '0.104.143.66',
#   'srcport': 61435,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 20,
#   'packets': 498,
#   'bytes': 639800},
#  {'srcaddr': '0.104.144.142',
#   'srcport': 44055,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 0,
#   'packets': 327,
#   'bytes': 240668},
#  {'srcaddr': '0.104.179.229',
#   'srcport': 25415,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 6,
#   'packets': 226,
#   'bytes': 685243},
#  {'srcaddr': '0.104.182.156',
#   'srcport': 38968,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 23,
#   'packets': 200,
#   'bytes': 273976},
#  {'srcaddr': '0.104.185.214',
#   'srcport': 41084,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 16,
#   'packets': 211,
#   'bytes': 407811},
#  {'srcaddr': '0.104.190.20',
#   'srcport': 50720,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 9,
#   'packets': 273,
#   'bytes': 263538},
#  {'srcaddr': '0.104.201.199',
#   'srcport': 63169,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 20,
#   'packets': 158,
#   'bytes': 281551},
#  {'srcaddr': '0.104.246.9',
#   'srcport': 36657,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 18,
#   'packets': 79,
#   'bytes': 239286},
#  {'srcaddr': '0.104.248.120',
#   'srcport': 47166,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 13,
#   'packets': 421,
#   'bytes': 906702},
#  {'srcaddr': '0.104.45.37',
#   'srcport': 61134,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 30,
#   'packets': 104,
#   'bytes': 840928},
#  {'srcaddr': '0.104.59.5',
#   'srcport': 60034,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 27,
#   'packets': 294,
#   'bytes': 195555},
#  {'srcaddr': '0.104.7.111',
#   'srcport': 55273,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 30,
#   'packets': 483,
#   'bytes': 645675},
#  {'srcaddr': '0.105.104.228',
#   'srcport': 41851,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 28,
#   'packets': 69,
#   'bytes': 69499},
#  {'srcaddr': '0.105.142.113',
#   'srcport': 27450,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 23,
#   'packets': 173,
#   'bytes': 320064},
#  {'srcaddr': '0.105.147.168',
#   'srcport': 49224,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 20,
#   'packets': 80,
#   'bytes': 852835},
#  {'srcaddr': '0.105.152.14',
#   'srcport': 26578,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 13,
#   'packets': 396,
#   'bytes': 255345},
#  {'srcaddr': '0.105.153.129',
#   'srcport': 57782,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 14,
#   'packets': 107,
#   'bytes': 587566},
#  {'srcaddr': '0.105.157.195',
#   'srcport': 13406,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 15,
#   'packets': 421,
#   'bytes': 337593},
#  {'srcaddr': '0.105.165.230',
#   'srcport': 33053,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 7,
#   'packets': 399,
#   'bytes': 991579},
#  {'srcaddr': '0.105.170.86',
#   'srcport': 54767,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 6,
#   'packets': 264,
#   'bytes': 286339},
#  {'srcaddr': '0.105.18.115',
#   'srcport': 59790,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 21,
#   'packets': 200,
#   'bytes': 962068},
#  {'srcaddr': '0.105.204.180',
#   'srcport': 40863,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 25,
#   'packets': 232,
#   'bytes': 14182},
#  {'srcaddr': '0.105.23.145',
#   'srcport': 25223,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 0,
#   'packets': 284,
#   'bytes': 656489},
#  {'srcaddr': '0.105.51.57',
#   'srcport': 296,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 16,
#   'packets': 165,
#   'bytes': 662710},
#  {'srcaddr': '0.105.66.17',
#   'srcport': 5878,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 10,
#   'packets': 143,
#   'bytes': 903001},
#  {'srcaddr': '0.105.77.67',
#   'srcport': 28810,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 16,
#   'packets': 45,
#   'bytes': 425130},
#  {'srcaddr': '0.105.79.10',
#   'srcport': 45999,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 16,
#   'packets': 374,
#   'bytes': 936654},
#  {'srcaddr': '0.105.90.143',
#   'srcport': 63828,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 18,
#   'packets': 220,
#   'bytes': 330924},
#  {'srcaddr': '0.105.99.216',
#   'srcport': 3755,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 26,
#   'packets': 382,
#   'bytes': 698268},
#  {'srcaddr': '0.106.1.155',
#   'srcport': 40981,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 18,
#   'packets': 209,
#   'bytes': 569383},
#  {'srcaddr': '0.106.119.195',
#   'srcport': 9481,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 9,
#   'packets': 148,
#   'bytes': 400310},
#  {'srcaddr': '0.106.124.81',
#   'srcport': 51316,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 18,
#   'packets': 179,
#   'bytes': 225946},
#  {'srcaddr': '0.106.135.156',
#   'srcport': 6844,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 6,
#   'packets': 487,
#   'bytes': 550414},
#  {'srcaddr': '0.106.17.68',
#   'srcport': 53556,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 19,
#   'packets': 328,
#   'bytes': 181617},
#  {'srcaddr': '0.106.178.186',
#   'srcport': 27186,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 28,
#   'packets': 48,
#   'bytes': 849644},
#  {'srcaddr': '0.106.201.141',
#   'srcport': 18960,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 10,
#   'packets': 72,
#   'bytes': 185365},
#  {'srcaddr': '0.106.220.215',
#   'srcport': 51928,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 1,
#   'packets': 59,
#   'bytes': 817479},
#  {'srcaddr': '0.106.225.98',
#   'srcport': 13111,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 6,
#   'packets': 461,
#   'bytes': 668715},
#  {'srcaddr': '0.106.247.189',
#   'srcport': 25708,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 30,
#   'packets': 421,
#   'bytes': 2158},
#  {'srcaddr': '0.106.60.11',
#   'srcport': 18661,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 25,
#   'packets': 167,
#   'bytes': 594104},
#  {'srcaddr': '0.106.70.10',
#   'srcport': 33605,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 0,
#   'packets': 33,
#   'bytes': 358094},
#  {'srcaddr': '0.106.70.148',
#   'srcport': 30823,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 10,
#   'packets': 70,
#   'bytes': 515660},
#  {'srcaddr': '0.106.80.216',
#   'srcport': 17254,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 21,
#   'packets': 2,
#   'bytes': 730979},
#  {'srcaddr': '0.106.84.248',
#   'srcport': 41476,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 4,
#   'packets': 172,
#   'bytes': 855357},
#  {'srcaddr': '0.106.95.135',
#   'srcport': 44211,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 14,
#   'packets': 65,
#   'bytes': 517860},
#  {'srcaddr': '0.106.99.73',
#   'srcport': 16631,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 0,
#   'packets': 195,
#   'bytes': 849910},
#  {'srcaddr': '0.107.135.252',
#   'srcport': 49663,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 12,
#   'packets': 37,
#   'bytes': 236470},
#  {'srcaddr': '0.107.139.179',
#   'srcport': 47147,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 15,
#   'packets': 403,
#   'bytes': 947834},
#  {'srcaddr': '0.107.143.40',
#   'srcport': 36537,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 6,
#   'packets': 498,
#   'bytes': 175602},
#  {'srcaddr': '0.107.165.31',
#   'srcport': 17573,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 21,
#   'packets': 354,
#   'bytes': 102419},
#  {'srcaddr': '0.107.174.234',
#   'srcport': 38928,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 29,
#   'packets': 158,
#   'bytes': 117675},
#  {'srcaddr': '0.107.196.255',
#   'srcport': 60890,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 28,
#   'packets': 84,
#   'bytes': 665936},
#  {'srcaddr': '0.107.198.156',
#   'srcport': 47587,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 25,
#   'packets': 268,
#   'bytes': 288973},
#  {'srcaddr': '0.107.243.98',
#   'srcport': 34014,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 1,
#   'packets': 89,
#   'bytes': 219700},
#  {'srcaddr': '0.107.27.141',
#   'srcport': 6978,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 18,
#   'packets': 129,
#   'bytes': 292332},
#  {'srcaddr': '0.107.64.106',
#   'srcport': 1226,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 15,
#   'packets': 277,
#   'bytes': 907493},
#  {'srcaddr': '0.107.90.180',
#   'srcport': 53555,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 24,
#   'packets': 403,
#   'bytes': 661058},
#  {'srcaddr': '0.107.97.247',
#   'srcport': 40871,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 22,
#   'packets': 498,
#   'bytes': 892279},
#  {'srcaddr': '0.108.100.94',
#   'srcport': 39233,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 15,
#   'packets': 478,
#   'bytes': 408495},
#  {'srcaddr': '0.108.129.2',
#   'srcport': 5629,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 2,
#   'packets': 375,
#   'bytes': 379842},
#  {'srcaddr': '0.108.13.204',
#   'srcport': 51821,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 16,
#   'packets': 391,
#   'bytes': 439879},
#  {'srcaddr': '0.108.135.36',
#   'srcport': 13015,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 14,
#   'packets': 358,
#   'bytes': 208249},
#  {'srcaddr': '0.108.144.110',
#   'srcport': 9914,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 17,
#   'packets': 221,
#   'bytes': 359069},
#  {'srcaddr': '0.108.153.42',
#   'srcport': 23459,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 20,
#   'packets': 358,
#   'bytes': 93424},
#  {'srcaddr': '0.108.158.2',
#   'srcport': 49499,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 9,
#   'packets': 284,
#   'bytes': 912670},
#  {'srcaddr': '0.108.174.232',
#   'srcport': 17336,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 5,
#   'packets': 261,
#   'bytes': 326202},
#  {'srcaddr': '0.108.190.143',
#   'srcport': 4939,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 13,
#   'packets': 111,
#   'bytes': 807756},
#  {'srcaddr': '0.108.199.82',
#   'srcport': 27076,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 8,
#   'packets': 365,
#   'bytes': 283862},
#  {'srcaddr': '0.108.219.123',
#   'srcport': 4024,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 13,
#   'packets': 468,
#   'bytes': 727079},
#  {'srcaddr': '0.108.227.241',
#   'srcport': 24138,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 19,
#   'packets': 408,
#   'bytes': 188963},
#  {'srcaddr': '0.108.230.126',
#   'srcport': 4763,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 13,
#   'packets': 194,
#   'bytes': 880995},
#  {'srcaddr': '0.108.245.71',
#   'srcport': 8206,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 30,
#   'packets': 115,
#   'bytes': 235363},
#  {'srcaddr': '0.108.252.59',
#   'srcport': 41603,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 18,
#   'packets': 219,
#   'bytes': 440413},
#  {'srcaddr': '0.108.40.171',
#   'srcport': 63559,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 9,
#   'packets': 489,
#   'bytes': 122698},
#  {'srcaddr': '0.108.46.58',
#   'srcport': 34656,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 24,
#   'packets': 303,
#   'bytes': 460576},
#  {'srcaddr': '0.108.79.61',
#   'srcport': 24162,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 28,
#   'packets': 175,
#   'bytes': 94547},
#  {'srcaddr': '0.108.95.218',
#   'srcport': 50801,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 16,
#   'packets': 196,
#   'bytes': 521234},
#  {'srcaddr': '0.109.125.94',
#   'srcport': 54552,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 12,
#   'packets': 303,
#   'bytes': 182898},
#  {'srcaddr': '0.109.199.218',
#   'srcport': 3444,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 16,
#   'packets': 137,
#   'bytes': 8686},
#  {'srcaddr': '0.109.2.50',
#   'srcport': 19207,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 1,
#   'packets': 397,
#   'bytes': 638594},
#  {'srcaddr': '0.109.31.21',
#   'srcport': 2956,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 22,
#   'packets': 378,
#   'bytes': 824551},
#  {'srcaddr': '0.109.56.201',
#   'srcport': 8471,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 16,
#   'packets': 123,
#   'bytes': 572039},
#  {'srcaddr': '0.109.6.156',
#   'srcport': 36794,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 17,
#   'packets': 500,
#   'bytes': 801794},
#  {'srcaddr': '0.109.62.235',
#   'srcport': 59617,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 27,
#   'packets': 284,
#   'bytes': 104315},
#  {'srcaddr': '0.109.63.30',
#   'srcport': 63276,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 16,
#   'packets': 346,
#   'bytes': 519656},
#  {'srcaddr': '0.109.78.189',
#   'srcport': 58714,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 24,
#   'packets': 37,
#   'bytes': 223746},
#  {'srcaddr': '0.11.143.206',
#   'srcport': 524,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 26,
#   'packets': 340,
#   'bytes': 329436},
#  {'srcaddr': '0.11.143.63',
#   'srcport': 17980,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 8,
#   'packets': 37,
#   'bytes': 588932},
#  {'srcaddr': '0.11.169.53',
#   'srcport': 35940,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 2,
#   'packets': 319,
#   'bytes': 494144},
#  {'srcaddr': '0.11.192.98',
#   'srcport': 42926,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 0,
#   'packets': 481,
#   'bytes': 978408},
#  {'srcaddr': '0.11.196.187',
#   'srcport': 43862,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 3,
#   'packets': 478,
#   'bytes': 720821},
#  {'srcaddr': '0.11.196.208',
#   'srcport': 15031,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 10,
#   'packets': 249,
#   'bytes': 894955},
#  {'srcaddr': '0.11.220.37',
#   'srcport': 32163,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 10,
#   'packets': 345,
#   'bytes': 379513},
#  {'srcaddr': '0.11.244.43',
#   'srcport': 41020,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 26,
#   'packets': 417,
#   'bytes': 544823},
#  {'srcaddr': '0.11.3.215',
#   'srcport': 269,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 21,
#   'packets': 98,
#   'bytes': 368638},
#  {'srcaddr': '0.11.49.20',
#   'srcport': 64730,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 11,
#   'packets': 407,
#   'bytes': 931941},
#  {'srcaddr': '0.11.67.59',
#   'srcport': 6563,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 6,
#   'packets': 303,
#   'bytes': 856576},
#  {'srcaddr': '0.110.106.124',
#   'srcport': 10088,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 2,
#   'packets': 380,
#   'bytes': 796756},
#  {'srcaddr': '0.110.125.21',
#   'srcport': 31760,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 18,
#   'packets': 61,
#   'bytes': 364814},
#  {'srcaddr': '0.110.146.141',
#   'srcport': 47948,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 0,
#   'packets': 139,
#   'bytes': 908772},
#  {'srcaddr': '0.110.164.150',
#   'srcport': 50140,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 25,
#   'packets': 161,
#   'bytes': 752329},
#  {'srcaddr': '0.110.183.171',
#   'srcport': 54563,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 6,
#   'packets': 434,
#   'bytes': 901820},
#  {'srcaddr': '0.110.215.32',
#   'srcport': 39518,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 9,
#   'packets': 189,
#   'bytes': 330296},
#  {'srcaddr': '0.110.31.64',
#   'srcport': 39947,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 17,
#   'packets': 101,
#   'bytes': 679995},
#  {'srcaddr': '0.110.49.115',
#   'srcport': 38279,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 11,
#   'packets': 53,
#   'bytes': 379814},
#  {'srcaddr': '0.110.5.143',
#   'srcport': 40653,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 7,
#   'packets': 386,
#   'bytes': 869437},
#  {'srcaddr': '0.110.5.155',
#   'srcport': 9089,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 2,
#   'packets': 240,
#   'bytes': 573334},
#  {'srcaddr': '0.110.58.226',
#   'srcport': 57734,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 5,
#   'packets': 152,
#   'bytes': 235075},
#  {'srcaddr': '0.110.6.239',
#   'srcport': 46077,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 8,
#   'packets': 376,
#   'bytes': 41956},
#  {'srcaddr': '0.110.69.26',
#   'srcport': 45218,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 5,
#   'packets': 445,
#   'bytes': 63085},
#  {'srcaddr': '0.110.7.243',
#   'srcport': 53556,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 2,
#   'packets': 62,
#   'bytes': 4591},
#  {'srcaddr': '0.110.84.241',
#   'srcport': 20473,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 19,
#   'packets': 373,
#   'bytes': 994538},
#  {'srcaddr': '0.110.86.9',
#   'srcport': 61151,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 15,
#   'packets': 245,
#   'bytes': 539944},
#  {'srcaddr': '0.111.134.212',
#   'srcport': 30793,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 22,
#   'packets': 43,
#   'bytes': 724803},
#  {'srcaddr': '0.111.162.44',
#   'srcport': 21013,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 2,
#   'packets': 483,
#   'bytes': 33688},
#  {'srcaddr': '0.111.220.23',
#   'srcport': 20278,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 17,
#   'packets': 177,
#   'bytes': 677097},
#  {'srcaddr': '0.111.233.200',
#   'srcport': 45285,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 4,
#   'packets': 323,
#   'bytes': 987316},
#  {'srcaddr': '0.111.242.63',
#   'srcport': 8154,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 27,
#   'packets': 380,
#   'bytes': 84472},
#  {'srcaddr': '0.111.37.32',
#   'srcport': 58414,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 1,
#   'packets': 442,
#   'bytes': 736738},
#  {'srcaddr': '0.111.41.169',
#   'srcport': 21083,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 20,
#   'packets': 82,
#   'bytes': 155910},
#  {'srcaddr': '0.111.66.59',
#   'srcport': 31052,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 19,
#   'packets': 351,
#   'bytes': 98238},
#  {'srcaddr': '0.111.79.63',
#   'srcport': 33754,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 27,
#   'packets': 482,
#   'bytes': 869746},
#  {'srcaddr': '0.111.86.142',
#   'srcport': 45123,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 16,
#   'packets': 186,
#   'bytes': 924862},
#  {'srcaddr': '0.112.11.229',
#   'srcport': 40247,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 18,
#   'packets': 153,
#   'bytes': 205624},
#  {'srcaddr': '0.112.113.23',
#   'srcport': 37811,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 12,
#   'packets': 179,
#   'bytes': 890905},
#  {'srcaddr': '0.112.115.67',
#   'srcport': 44315,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 21,
#   'packets': 133,
#   'bytes': 422109},
#  {'srcaddr': '0.112.122.17',
#   'srcport': 6442,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 12,
#   'packets': 1,
#   'bytes': 257956},
#  {'srcaddr': '0.112.142.22',
#   'srcport': 57659,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 18,
#   'packets': 372,
#   'bytes': 260376},
#  {'srcaddr': '0.112.148.55',
#   'srcport': 12476,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 3,
#   'packets': 2,
#   'bytes': 440890},
#  {'srcaddr': '0.112.15.88',
#   'srcport': 9413,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 3,
#   'packets': 474,
#   'bytes': 543986},
#  {'srcaddr': '0.112.174.133',
#   'srcport': 38892,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 0,
#   'packets': 188,
#   'bytes': 862138},
#  {'srcaddr': '0.112.208.176',
#   'srcport': 9606,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 20,
#   'packets': 347,
#   'bytes': 476940},
#  {'srcaddr': '0.112.238.155',
#   'srcport': 4921,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 20,
#   'packets': 219,
#   'bytes': 503481},
#  {'srcaddr': '0.112.243.221',
#   'srcport': 38007,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 18,
#   'packets': 338,
#   'bytes': 506934},
#  {'srcaddr': '0.112.243.72',
#   'srcport': 31276,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 24,
#   'packets': 429,
#   'bytes': 825263},
#  {'srcaddr': '0.112.249.53',
#   'srcport': 5422,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 10,
#   'packets': 259,
#   'bytes': 541156},
#  {'srcaddr': '0.112.56.212',
#   'srcport': 59001,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 8,
#   'packets': 414,
#   'bytes': 915045},
#  {'srcaddr': '0.112.58.244',
#   'srcport': 19021,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 30,
#   'packets': 191,
#   'bytes': 413766},
#  {'srcaddr': '0.112.69.6',
#   'srcport': 6420,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 10,
#   'packets': 171,
#   'bytes': 80552},
#  {'srcaddr': '0.112.96.99',
#   'srcport': 930,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 2,
#   'packets': 29,
#   'bytes': 111268},
#  {'srcaddr': '0.113.100.117',
#   'srcport': 19754,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 9,
#   'packets': 365,
#   'bytes': 785992},
#  {'srcaddr': '0.113.114.28',
#   'srcport': 22613,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 2,
#   'packets': 471,
#   'bytes': 408793},
#  {'srcaddr': '0.113.123.20',
#   'srcport': 40518,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 28,
#   'packets': 219,
#   'bytes': 796728},
#  {'srcaddr': '0.113.140.124',
#   'srcport': 20025,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 3,
#   'packets': 454,
#   'bytes': 852527},
#  {'srcaddr': '0.113.144.120',
#   'srcport': 17418,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 15,
#   'packets': 465,
#   'bytes': 819712},
#  {'srcaddr': '0.113.17.202',
#   'srcport': 6092,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 23,
#   'packets': 473,
#   'bytes': 989242},
#  {'srcaddr': '0.113.174.217',
#   'srcport': 37027,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 12,
#   'packets': 398,
#   'bytes': 558119},
#  {'srcaddr': '0.113.217.60',
#   'srcport': 59603,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 16,
#   'packets': 247,
#   'bytes': 466888},
#  {'srcaddr': '0.113.219.77',
#   'srcport': 31454,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 24,
#   'packets': 491,
#   'bytes': 260657},
#  {'srcaddr': '0.113.221.39',
#   'srcport': 45624,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 13,
#   'packets': 61,
#   'bytes': 705453},
#  {'srcaddr': '0.113.232.208',
#   'srcport': 4565,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 25,
#   'packets': 441,
#   'bytes': 503993},
#  {'srcaddr': '0.113.233.44',
#   'srcport': 50570,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 22,
#   'packets': 173,
#   'bytes': 633910},
#  {'srcaddr': '0.113.240.136',
#   'srcport': 655,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 9,
#   'packets': 70,
#   'bytes': 371999},
#  {'srcaddr': '0.113.255.99',
#   'srcport': 24270,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 18,
#   'packets': 124,
#   'bytes': 316982},
#  {'srcaddr': '0.113.39.136',
#   'srcport': 46548,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 5,
#   'packets': 376,
#   'bytes': 684887},
#  {'srcaddr': '0.113.43.104',
#   'srcport': 12778,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 13,
#   'packets': 401,
#   'bytes': 685567},
#  {'srcaddr': '0.113.43.225',
#   'srcport': 26494,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 9,
#   'packets': 338,
#   'bytes': 676537},
#  {'srcaddr': '0.113.53.40',
#   'srcport': 5673,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 11,
#   'packets': 114,
#   'bytes': 237017},
#  {'srcaddr': '0.113.55.176',
#   'srcport': 34982,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 27,
#   'packets': 153,
#   'bytes': 15389},
#  {'srcaddr': '0.113.8.10',
#   'srcport': 28260,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 26,
#   'packets': 481,
#   'bytes': 976920},
#  {'srcaddr': '0.114.105.252',
#   'srcport': 62185,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 13,
#   'packets': 297,
#   'bytes': 418722},
#  {'srcaddr': '0.114.12.135',
#   'srcport': 59767,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 6,
#   'packets': 157,
#   'bytes': 575410},
#  {'srcaddr': '0.114.146.228',
#   'srcport': 39560,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 6,
#   'packets': 420,
#   'bytes': 485877},
#  {'srcaddr': '0.114.151.169',
#   'srcport': 50841,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 30,
#   'packets': 157,
#   'bytes': 185342},
#  {'srcaddr': '0.114.151.174',
#   'srcport': 1076,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 18,
#   'packets': 266,
#   'bytes': 115244},
#  {'srcaddr': '0.114.158.57',
#   'srcport': 59626,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 10,
#   'packets': 2,
#   'bytes': 533024},
#  {'srcaddr': '0.114.163.184',
#   'srcport': 23624,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 7,
#   'packets': 275,
#   'bytes': 414166},
#  {'srcaddr': '0.114.17.70',
#   'srcport': 30711,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 17,
#   'packets': 353,
#   'bytes': 602179},
#  {'srcaddr': '0.114.173.182',
#   'srcport': 47975,
#   'First': 20200528141258,
# ...
#   'flows': 0,
#   'packets': 128,
#   'bytes': 970},
#  {'srcaddr': '0.153.222.70',
#   'srcport': 31225,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 3,
#   'packets': 317,
#   'bytes': 599141},
#  {'srcaddr': '0.153.244.67',
#   'srcport': 40321,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 1,
#   'packets': 268,
#   'bytes': 459831},
#  {'srcaddr': '0.153.246.51',
#   'srcport': 40138,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 10,
#   'packets': 388,
#   'bytes': 43697},
#  {'srcaddr': '0.153.3.161',
#   'srcport': 40292,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 14,
#   'packets': 31,
#   'bytes': 904432},
#  {'srcaddr': '0.153.62.159',
#   'srcport': 38803,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 11,
#   'packets': 478,
#   'bytes': 623624},
#  {'srcaddr': '0.153.7.251',
#   'srcport': 9070,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 5,
#   'packets': 47,
#   'bytes': 449687},
#  {'srcaddr': '0.154.0.254',
#   'srcport': 26594,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 14,
#   'packets': 96,
#   'bytes': 868799},
#  {'srcaddr': '0.154.103.243',
#   'srcport': 52550,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 29,
#   'packets': 467,
#   'bytes': 924393},
#  {'srcaddr': '0.154.128.20',
#   'srcport': 33978,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 5,
#   'packets': 343,
#   'bytes': 711098},
#  {'srcaddr': '0.154.131.171',
#   'srcport': 56417,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 2,
#   'packets': 144,
#   'bytes': 877330},
#  {'srcaddr': '0.154.150.116',
#   'srcport': 15188,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 17,
#   'packets': 455,
#   'bytes': 202153},
#  {'srcaddr': '0.154.178.45',
#   'srcport': 25645,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 6,
#   'packets': 218,
#   'bytes': 223680},
#  {'srcaddr': '0.154.18.245',
#   'srcport': 1207,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 17,
#   'packets': 69,
#   'bytes': 441967},
#  {'srcaddr': '0.154.182.222',
#   'srcport': 6869,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 8,
#   'packets': 268,
#   'bytes': 381348},
#  {'srcaddr': '0.154.183.92',
#   'srcport': 59236,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 0,
#   'packets': 167,
#   'bytes': 954539},
#  {'srcaddr': '0.154.189.119',
#   'srcport': 53,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 26,
#   'packets': 168,
#   'bytes': 573639},
#  {'srcaddr': '0.154.203.130',
#   'srcport': 3778,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 1,
#   'packets': 484,
#   'bytes': 591194},
#  {'srcaddr': '0.154.235.203',
#   'srcport': 209,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 14,
#   'packets': 265,
#   'bytes': 715914},
#  {'srcaddr': '0.154.238.254',
#   'srcport': 30350,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 3,
#   'packets': 464,
#   'bytes': 207162},
#  {'srcaddr': '0.154.243.11',
#   'srcport': 33837,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 29,
#   'packets': 469,
#   'bytes': 147584},
#  {'srcaddr': '0.154.251.95',
#   'srcport': 53130,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 28,
#   'packets': 278,
#   'bytes': 802304},
#  {'srcaddr': '0.154.3.197',
#   'srcport': 33056,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 24,
#   'packets': 198,
#   'bytes': 642710},
#  {'srcaddr': '0.154.42.78',
#   'srcport': 56456,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 8,
#   'packets': 483,
#   'bytes': 60862},
#  {'srcaddr': '0.154.73.74',
#   'srcport': 2807,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 9,
#   'packets': 67,
#   'bytes': 123584},
#  {'srcaddr': '0.154.8.75',
#   'srcport': 30914,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 14,
#   'packets': 381,
#   'bytes': 667993},
#  {'srcaddr': '0.155.0.207',
#   'srcport': 18021,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 16,
#   'packets': 477,
#   'bytes': 217792},
#  {'srcaddr': '0.155.117.62',
#   'srcport': 27111,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 9,
#   'packets': 82,
#   'bytes': 823558},
#  {'srcaddr': '0.155.136.197',
#   'srcport': 42072,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 20,
#   'packets': 43,
#   'bytes': 725888},
#  {'srcaddr': '0.155.142.174',
#   'srcport': 14384,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 0,
#   'packets': 448,
#   'bytes': 683050},
#  {'srcaddr': '0.155.143.142',
#   'srcport': 59021,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 30,
#   'packets': 273,
#   'bytes': 447173},
#  {'srcaddr': '0.155.163.156',
#   'srcport': 63432,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 24,
#   'packets': 18,
#   'bytes': 699079},
#  {'srcaddr': '0.155.191.80',
#   'srcport': 12985,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 22,
#   'packets': 60,
#   'bytes': 503048},
#  {'srcaddr': '0.155.195.195',
#   'srcport': 50923,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 1,
#   'packets': 34,
#   'bytes': 962304},
#  {'srcaddr': '0.155.2.144',
#   'srcport': 14352,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 25,
#   'packets': 159,
#   'bytes': 78947},
#  {'srcaddr': '0.155.202.146',
#   'srcport': 2938,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 27,
#   'packets': 420,
#   'bytes': 98763},
#  {'srcaddr': '0.155.228.63',
#   'srcport': 8337,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 27,
#   'packets': 446,
#   'bytes': 692086},
#  {'srcaddr': '0.155.30.144',
#   'srcport': 49341,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 16,
#   'packets': 30,
#   'bytes': 40072},
#  {'srcaddr': '0.155.38.136',
#   'srcport': 599,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 21,
#   'packets': 463,
#   'bytes': 694225},
#  {'srcaddr': '0.155.53.43',
#   'srcport': 39380,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 1,
#   'packets': 332,
#   'bytes': 245120},
#  {'srcaddr': '0.155.96.156',
#   'srcport': 5095,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 30,
#   'packets': 469,
#   'bytes': 242981},
#  {'srcaddr': '0.156.1.115',
#   'srcport': 57066,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 7,
#   'packets': 264,
#   'bytes': 918864},
#  {'srcaddr': '0.156.135.104',
#   'srcport': 9311,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 7,
#   'packets': 198,
#   'bytes': 173620},
#  {'srcaddr': '0.156.135.86',
#   'srcport': 5547,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 11,
#   'packets': 290,
#   'bytes': 372604},
#  {'srcaddr': '0.156.14.137',
#   'srcport': 34368,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 29,
#   'packets': 192,
#   'bytes': 456019},
#  {'srcaddr': '0.156.180.247',
#   'srcport': 9048,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 25,
#   'packets': 366,
#   'bytes': 298337},
#  {'srcaddr': '0.156.2.33',
#   'srcport': 4034,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 0,
#   'packets': 128,
#   'bytes': 798837},
#  {'srcaddr': '0.156.209.18',
#   'srcport': 8606,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 14,
#   'packets': 187,
#   'bytes': 459973},
#  {'srcaddr': '0.156.217.90',
#   'srcport': 58960,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 0,
#   'packets': 137,
#   'bytes': 387779},
#  {'srcaddr': '0.156.237.207',
#   'srcport': 49412,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 3,
#   'packets': 83,
#   'bytes': 195057},
#  {'srcaddr': '0.156.255.93',
#   'srcport': 33807,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 4,
#   'packets': 126,
#   'bytes': 571631},
#  {'srcaddr': '0.156.26.66',
#   'srcport': 48667,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 11,
#   'packets': 456,
#   'bytes': 516193},
#  {'srcaddr': '0.156.63.148',
#   'srcport': 64417,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 3,
#   'packets': 8,
#   'bytes': 792161},
#  {'srcaddr': '0.156.66.104',
#   'srcport': 35263,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 22,
#   'packets': 452,
#   'bytes': 387062},
#  {'srcaddr': '0.157.101.115',
#   'srcport': 57384,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 27,
#   'packets': 96,
#   'bytes': 130098},
#  {'srcaddr': '0.157.111.48',
#   'srcport': 57367,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 6,
#   'packets': 61,
#   'bytes': 77588},
#  {'srcaddr': '0.157.116.217',
#   'srcport': 39221,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 21,
#   'packets': 208,
#   'bytes': 774233},
#  {'srcaddr': '0.157.144.26',
#   'srcport': 44029,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 24,
#   'packets': 271,
#   'bytes': 281265},
#  {'srcaddr': '0.157.144.53',
#   'srcport': 10547,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 23,
#   'packets': 252,
#   'bytes': 785264},
#  {'srcaddr': '0.157.151.231',
#   'srcport': 17568,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 0,
#   'packets': 200,
#   'bytes': 986615},
#  {'srcaddr': '0.157.158.208',
#   'srcport': 37833,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 18,
#   'packets': 366,
#   'bytes': 503321},
#  {'srcaddr': '0.157.162.156',
#   'srcport': 55517,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 16,
#   'packets': 5,
#   'bytes': 484884},
#  {'srcaddr': '0.157.175.56',
#   'srcport': 6356,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 21,
#   'packets': 276,
#   'bytes': 548495},
#  {'srcaddr': '0.157.187.123',
#   'srcport': 39555,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 10,
#   'packets': 247,
#   'bytes': 850929},
#  {'srcaddr': '0.157.192.139',
#   'srcport': 57565,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 24,
#   'packets': 491,
#   'bytes': 937306},
#  {'srcaddr': '0.157.251.102',
#   'srcport': 20482,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 28,
#   'packets': 406,
#   'bytes': 202950},
#  {'srcaddr': '0.157.42.124',
#   'srcport': 1135,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 20,
#   'packets': 260,
#   'bytes': 699508},
#  {'srcaddr': '0.157.59.52',
#   'srcport': 26208,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 15,
#   'packets': 166,
#   'bytes': 907838},
#  {'srcaddr': '0.157.61.249',
#   'srcport': 54722,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 20,
#   'packets': 156,
#   'bytes': 299081},
#  {'srcaddr': '0.158.10.83',
#   'srcport': 16473,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 24,
#   'packets': 352,
#   'bytes': 418841},
#  {'srcaddr': '0.158.108.148',
#   'srcport': 51103,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 4,
#   'packets': 23,
#   'bytes': 674053},
#  {'srcaddr': '0.158.111.162',
#   'srcport': 32929,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 16,
#   'packets': 499,
#   'bytes': 867647},
#  {'srcaddr': '0.158.140.92',
#   'srcport': 34762,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 10,
#   'packets': 483,
#   'bytes': 428131},
#  {'srcaddr': '0.158.177.128',
#   'srcport': 4944,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 24,
#   'packets': 442,
#   'bytes': 656959},
#  {'srcaddr': '0.158.224.137',
#   'srcport': 12565,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 30,
#   'packets': 256,
#   'bytes': 323874},
#  {'srcaddr': '0.158.232.216',
#   'srcport': 59107,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 13,
#   'packets': 282,
#   'bytes': 916189},
#  {'srcaddr': '0.158.24.186',
#   'srcport': 64607,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 18,
#   'packets': 457,
#   'bytes': 268978},
#  {'srcaddr': '0.158.247.234',
#   'srcport': 46438,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 16,
#   'packets': 381,
#   'bytes': 524346},
#  {'srcaddr': '0.158.27.58',
#   'srcport': 8686,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 23,
#   'packets': 293,
#   'bytes': 412058},
#  {'srcaddr': '0.158.4.96',
#   'srcport': 28997,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 5,
#   'packets': 159,
#   'bytes': 369040},
#  {'srcaddr': '0.158.54.138',
#   'srcport': 41119,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 8,
#   'packets': 221,
#   'bytes': 515368},
#  {'srcaddr': '0.158.65.2',
#   'srcport': 16169,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 3,
#   'packets': 482,
#   'bytes': 258048},
#  {'srcaddr': '0.158.79.158',
#   'srcport': 9557,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 7,
#   'packets': 24,
#   'bytes': 58384},
#  {'srcaddr': '0.158.84.219',
#   'srcport': 20655,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'TCP',
#   'flows': 7,
#   'packets': 311,
#   'bytes': 865651},
#  {'srcaddr': '0.159.104.221',
#   'srcport': 16486,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 14,
#   'packets': 311,
#   'bytes': 744025},
#  {'srcaddr': '0.159.111.68',
#   'srcport': 8933,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 18,
#   'packets': 312,
#   'bytes': 972354},
#  {'srcaddr': '0.159.114.35',
#   'srcport': 48854,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 18,
#   'packets': 162,
#   'bytes': 355415},
#  {'srcaddr': '0.159.142.192',
#   'srcport': 52997,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 24,
#   'packets': 115,
#   'bytes': 766662},
#  {'srcaddr': '0.159.145.41',
#   'srcport': 16620,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 6,
#   'packets': 239,
#   'bytes': 704378},
#  {'srcaddr': '0.159.156.69',
#   'srcport': 11920,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'ssh',
#   'flows': 22,
#   'packets': 486,
#   'bytes': 308579},
#  {'srcaddr': '0.159.164.128',
#   'srcport': 6087,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 6,
#   'packets': 264,
#   'bytes': 233684},
#  {'srcaddr': '0.159.205.129',
#   'srcport': 63505,
#   'First': 20200528141258,
#   'Last': 20200528141758,
#   'protocol': 'UDP',
#   'flows': 22,
#   'packets': 325,
#   'bytes': 45098},
#  ...]

# %%
import time
import json

# update 1 X 1000000 records at a time
mydb.reconnect()
#for json_name in s:
mycursor = mydb.cursor()
sql_update = "INSERT INTO p_netflow (srcaddr, srcport, first, last, protocol, flows, packets, bytes) VALUES (%s,%s,%s,%s,%s,%s,%s,%s) ON DUPLICATE KEY UPDATE `last` = VALUES(`last`), `flows`= VALUES(`flows`) + `flows`, `packets`= VALUES(`packets`) + `packets`, `bytes`= VALUES(`bytes`) + `bytes`"

start_time = time.time()
flows = []
with open('data/netflow/' + s[2]) as record:
        new_record = json.load(record)
        new_record.sort(key=lambda k: (k.get('srcaddr', 0)))
        for flow in new_record:
            srcaddr = struct.unpack('!I', socket.inet_aton(flow["srcaddr"]))[0]
            protocol = protocol_to_number(flow["protocol"])
            flow_one = (srcaddr, flow["srcport"], flow["First"], flow["Last"], protocol, flow["flows"], flow["packets"], flow["bytes"])
            flows.append(flow_one)
        mycursor.executemany(sql_update, flows)
        mycursor.close()
        mydb.commit()    # 数据表内容有更新，必须使用到该语句
        mydb.close()
        print(mycursor.rowcount, "记录插入成功。")
        end_time = time.time()
        consume_time = end_time - start_time
        consume_time = '{:0>2s}'.format(str(int(consume_time // 3600))) \
               + ':{:0>2s}'.format(str(int((consume_time // 60) % 60))) \
               + ':{:0>2s}'.format(str(int(consume_time % 60)))
        print(consume_time)
# Out:
# -1 记录插入成功。
# 00:01:38

# %%
import time
import json

# update 1 X 1000000 records at a time
mydb.reconnect()
#for json_name in s:
mycursor = mydb.cursor()
sql_update = "INSERT INTO p_netflow (srcaddr, srcport, first, last, protocol, flows, packets, bytes) VALUES (%s,%s,%s,%s,%s,%s,%s,%s) ON DUPLICATE KEY UPDATE `last` = VALUES(`last`), `flows`= VALUES(`flows`) + `flows`, `packets`= VALUES(`packets`) + `packets`, `bytes`= VALUES(`bytes`) + `bytes`"

start_time = time.time()
flows = []
with open('data/netflow/' + s[3]) as record:
        new_record = json.load(record)
        new_record.sort(key=lambda k: (k.get('srcaddr', 0)))
        for flow in new_record:
            srcaddr = struct.unpack('!I', socket.inet_aton(flow["srcaddr"]))[0]
            protocol = protocol_to_number(flow["protocol"])
            flow_one = (srcaddr, flow["srcport"], flow["First"], flow["Last"], protocol, flow["flows"], flow["packets"], flow["bytes"])
            flows.append(flow_one)
        mycursor.executemany(sql_update, flows)
        mycursor.close()
        mydb.commit()    # 数据表内容有更新，必须使用到该语句
        mydb.close()
        print(mycursor.rowcount, "记录插入成功。")
        end_time = time.time()
        consume_time = end_time - start_time
        consume_time = '{:0>2s}'.format(str(int(consume_time // 3600))) \
               + ':{:0>2s}'.format(str(int((consume_time // 60) % 60))) \
               + ':{:0>2s}'.format(str(int(consume_time % 60)))
        print(consume_time)
# Out:
# -1 记录插入成功。
# 00:03:08

# %%
import time
import json

# update 1 X 1000000 records at a time
mydb.reconnect()
#for json_name in s:
mycursor = mydb.cursor()
sql_update = "INSERT INTO p_netflow (srcaddr, srcport, first, last, protocol, flows, packets, bytes) VALUES (%s,%s,%s,%s,%s,%s,%s,%s) ON DUPLICATE KEY UPDATE `last` = VALUES(`last`), `flows`= VALUES(`flows`) + `flows`, `packets`= VALUES(`packets`) + `packets`, `bytes`= VALUES(`bytes`) + `bytes`"

start_time = time.time()
flows = []
with open('data/netflow/' + s[1]) as record:
        new_record = json.load(record)
        new_record.sort(key=lambda k: (k.get('srcaddr', 0)))
        for flow in new_record:
            srcaddr = struct.unpack('!I', socket.inet_aton(flow["srcaddr"]))[0]
            protocol = protocol_to_number(flow["protocol"])
            flow_one = (srcaddr, flow["srcport"], flow["First"], flow["Last"], protocol, flow["flows"], flow["packets"], flow["bytes"])
            flows.append(flow_one)
        mycursor.executemany(sql_update, flows)
        mycursor.close()
        mydb.commit()    # 数据表内容有更新，必须使用到该语句
        mydb.close()
        print(mycursor.rowcount, "记录插入成功。")
        end_time = time.time()
        consume_time = end_time - start_time
        consume_time = '{:0>2s}'.format(str(int(consume_time // 3600))) \
               + ':{:0>2s}'.format(str(int((consume_time // 60) % 60))) \
               + ':{:0>2s}'.format(str(int(consume_time % 60)))
        print(consume_time)
# Out:
# -1 记录插入成功。
# 00:01:12

# %%
import time
import json

# update 1 X 1000000 records at a time
mydb.reconnect()
#for json_name in s:
mycursor = mydb.cursor()
sql_update = "INSERT INTO p_netflow (srcaddr, srcport, first, last, protocol, flows, packets, bytes) VALUES (%s,%s,%s,%s,%s,%s,%s,%s) ON DUPLICATE KEY UPDATE `last` = VALUES(`last`), `flows`= VALUES(`flows`) + `flows`, `packets`= VALUES(`packets`) + `packets`, `bytes`= VALUES(`bytes`) + `bytes`"

start_time = time.time()
flows = []
with open('data/netflow/' + s[3]) as record:
        new_record = json.load(record)
        new_record.sort(key=lambda k: (k.get('srcaddr', 0)))
        for flow in new_record:
            srcaddr = struct.unpack('!I', socket.inet_aton(flow["srcaddr"]))[0]
            protocol = protocol_to_number(flow["protocol"])
            flow_one = (srcaddr, flow["srcport"], flow["First"], flow["Last"], protocol, flow["flows"], flow["packets"], flow["bytes"])
            flows.append(flow_one)
        mycursor.executemany(sql_update, flows)
        mycursor.close()
        mydb.commit()    # 数据表内容有更新，必须使用到该语句
        mydb.close()
        print(mycursor.rowcount, "记录插入成功。")
        end_time = time.time()
        consume_time = end_time - start_time
        consume_time = '{:0>2s}'.format(str(int(consume_time // 3600))) \
               + ':{:0>2s}'.format(str(int((consume_time // 60) % 60))) \
               + ':{:0>2s}'.format(str(int(consume_time % 60)))
        print(consume_time)
# Out:
# -1 记录插入成功。
# 00:01:29

# %%
import time
import json

# update 1 X 1000000 records at a time
mydb.reconnect()
#for json_name in s:
mycursor = mydb.cursor()
sql_update = "INSERT INTO p_netflow (srcaddr, srcport, first, last, protocol, flows, packets, bytes) VALUES (%s,%s,%s,%s,%s,%s,%s,%s) ON DUPLICATE KEY UPDATE `last` = VALUES(`last`), `flows`= VALUES(`flows`) + `flows`, `packets`= VALUES(`packets`) + `packets`, `bytes`= VALUES(`bytes`) + `bytes`"

start_time = time.time()
flows = []
with open('data/netflow/' + s[3]) as record:
        new_record = json.load(record)
        new_record.sort(key=lambda k: (k.get('srcaddr', 0)))
        for flow in new_record:
            srcaddr = struct.unpack('!I', socket.inet_aton(flow["srcaddr"]))[0]
            protocol = protocol_to_number(flow["protocol"])
            flow_one = (srcaddr, flow["srcport"], flow["First"], flow["Last"], protocol, flow["flows"], flow["packets"], flow["bytes"])
            flows.append(flow_one)
        mycursor.executemany(sql_update, flows)
        mycursor.close()
        mydb.commit()    # 数据表内容有更新，必须使用到该语句
        mydb.close()
        print(mycursor.rowcount, "记录插入成功。")
        end_time = time.time()
        consume_time = end_time - start_time
        consume_time = '{:0>2s}'.format(str(int(consume_time // 3600))) \
               + ':{:0>2s}'.format(str(int((consume_time // 60) % 60))) \
               + ':{:0>2s}'.format(str(int(consume_time % 60)))
        print(consume_time)
